# %% [markdown]
# # MM&A Supermarket Case

# %% [markdown]
# ## 1. Exploring the Data (EDA)

# %%
# importing necessary libraries
import numpy as np
import pandas as pd

# %%
# reading in the csv file into a dataframe
file = 'mma_mart.csv'
df = pd.read_csv(file)

# %%
# observing the data structure
df.head()
# Out:
#    order_id  product_id                                   product_name  \
# 0         1       49302                               Bulgarian Yogurt
# 1         1       11109  Organic 4% Milk Fat Whole Milk Cottage Cheese
# 2         1       10246                          Organic Celery Hearts
# 3         1       49683                                 Cucumber Kirby
# 4         1       43633           Lightly Smoked Sardines in Olive Oil
#
#    aisle_id                 aisle  department_id    department
# 0       120                yogurt             16    dairy eggs
# 1       108  other creams cheeses             16    dairy eggs
# 2        83      fresh vegetables              4       produce
# 3        83      fresh vegetables              4       produce
# 4        95   canned meat seafood             15  canned goods

# %%
# finding the shape of the data set (row and column)
df.shape
# Out:
# (987259, 7)

# %% [markdown]
# The data shows 987259 rows and 7 columns.

# %%
# finding amount of unique entries in each column
df.nunique()
# Out:
# order_id         97833
# product_id       35070
# product_name     35070
# aisle_id           134
# aisle              134
# department_id       21
# department          21
# dtype: int64

# %% [markdown]
# There are ~980000 items that were ordered over ~98000 orders and ~35000 unique products which is across 134 aisles that belong to 21 departments. This shows that selecting 1000-1200 products for the instabasket aisle is selecting only 1000/35000 = ~3% of the total product selection offered at MM&A supermarket.

# %% [markdown]
# Next, exploring the aisle and departments to maybe gain some insight on what products should be considered as refrigerant and frozen products.

# %%
df['aisle'].unique()
# Out:
# array(['yogurt', 'other creams cheeses', 'fresh vegetables',
#        'canned meat seafood', 'fresh fruits', 'packaged cheese', 'eggs',
#        'spices seasonings', 'oils vinegars', 'baking ingredients',
#        'doughs gelatins bake mixes', 'spreads',
#        'packaged vegetables fruits', 'soy lactosefree', 'poultry counter',
#        'bread', 'breakfast bakery', 'cold flu allergy',
#        'energy granola bars', 'breakfast bars pastries', 'chips pretzels',
#        'trail mix snack mix', 'crackers', 'refrigerated',
#        'energy sports drinks', 'salad dressing toppings',
#        'prepared soups salads', 'milk', 'paper goods',
#        'water seltzer sparkling water', 'kosher foods',
#        'packaged poultry', 'instant foods', 'packaged produce',
#        'cookies cakes', 'candy chocolate', 'body lotions soap',
#        'dry pasta', 'laundry', 'air fresheners candles', 'frozen produce',
#        'buns rolls', 'canned fruit applesauce', 'juice nectars',
#        'granola', 'fresh herbs', 'baby food formula',
#        'canned meals beans', 'cream', 'meat counter', 'frozen meals',
#        'fresh dips tapenades', 'soup broth bouillon',
#        'frozen meat seafood', 'frozen appetizers sides', 'dog food care',
#        'beers coolers', 'preserved dips spreads', 'spirits',
#        'soft drinks', 'coffee', 'frozen breakfast', 'cereal',
#        'frozen breads doughs', 'asian foods', 'soap', 'popcorn jerky',
#        'bulk dried fruits vegetables', 'butter', 'condiments',
#        'nuts seeds dried fruit', 'hot dogs bacon sausage',
#        'prepared meals', 'tofu meat alternatives', 'lunch meat',
#        'food storage', 'frozen vegan vegetarian', 'oral hygiene',
#        'ice cream ice', 'frozen pizza', 'canned jarred vegetables',
#        'pasta sauce', 'tea', 'grains rice dried goods',
#        'refrigerated pudding desserts', 'bakery desserts',
#        'specialty cheeses', 'mint gum', 'trash bags liners',
#        'honeys syrups nectars', 'muscles joints pain relief',
#        'tortillas flat bread', 'fruit vegetable snacks',
#        'plates bowls cups flatware', 'marinades meat preparation',
#        'kitchen supplies', 'frozen dessert', 'more household',
#        'hair care', 'seafood counter', 'frozen juice', 'beauty',
#        'bulk grains rice dried goods', 'missing', 'pickled goods olives',
#        'other', 'cleaning products', 'ice cream toppings', 'fresh pasta',
#        'dish detergents', 'latino foods', 'deodorants',
#        'packaged seafood', 'facial care', 'baby bath body care',
#        'feminine care', 'vitamins supplements', 'digestion',
#        'cat food care', 'protein meal replacements',
#        'hot cereal pancake mixes', 'baking supplies decor', 'shave needs',
#        'red wines', 'packaged meat', 'baby accessories',
#        'cocoa drink mixes', 'indian foods', 'diapers wipes', 'first aid',
#        'white wines', 'eye ear care', 'skin care',
#        'specialty wines champagnes'], dtype=object)

# %% [markdown]
# As can be seen from the aisle names, there are aisles with "frozen" such as `frozen produce` or `frozen meat seafood` in it which all products listed under these aisles would be considered for the 100 frozen product for instabasket. The same can't be said for refridgerant as there a lot of aisles to parse through so it might be better to look at the department to determine what department contains refridgerant products.

# %%
df['department'].unique()
# Out:
# array(['dairy eggs', 'produce', 'canned goods', 'pantry', 'meat seafood',
#        'bakery', 'personal care', 'snacks', 'breakfast', 'beverages',
#        'deli', 'household', 'international', 'dry goods pasta', 'frozen',
#        'babies', 'pets', 'alcohol', 'bulk', 'missing', 'other'],
#       dtype=object)

# %% [markdown]
# From the look at department names, `dairy eggs`, `produce`, `meat seafood`, `deli`, `frozen`, `missing` and `other` are all potential products for fridge and freezer space so it might be better to take a closer look at the products in those department.

# %%
dept_list = ['dairy eggs', 'produce', 'meat seafood', 'deli', 'frozen', 'missing', 'other']

# %%
# looking at products and aisles of those products for insight as well as how many products each department had
for department in dept_list:
    print(f"Department: {department}")
    print(f"Number of products: {df[df['department']==department]['product_name'].nunique()}\n")
    display(df[df['department']==department][['product_name', 'aisle']])
# Out:
# Department: dairy eggs
# Number of products: 2886
#                                              product_name  \
# 0                                        Bulgarian Yogurt
# 1           Organic 4% Milk Fat Whole Milk Cottage Cheese
# 7                             Organic Whole String Cheese
# 8                                      Organic Egg Whites
# 17      Total 2% with Strawberry Lowfat Greek Strained...
# ...                                                   ...
# 987240                        Large Grade AA Organic Eggs
# 987241                Reduced Fat Mozarella String Cheese
# 987242                   Vanilla Light & Fit Greek Yogurt
# 987243               Non-Fat Vanilla Blended Greek Yogurt
# 987254            Total 2% All Natural Plain Greek Yogurt
#
#                        aisle
# 0                     yogurt
# 1       other creams cheeses
# 7            packaged cheese
# 8                       eggs
# 17                    yogurt
# ...                      ...
# 987240                  eggs
# 987241       packaged cheese
# 987242                yogurt
# 987243                yogurt
# 987254                yogurt
#
# [164468 rows x 2 columns]
# Department: produce
# Number of products: 1437
#                      product_name                       aisle
# 2           Organic Celery Hearts            fresh vegetables
# 3                  Cucumber Kirby            fresh vegetables
# 5          Bag of Organic Bananas                fresh fruits
# 6            Organic Hass Avocado                fresh fruits
# 9           Michigan Organic Kale            fresh vegetables
# ...                           ...                         ...
# 987245                Gala Apples                fresh fruits
# 987246       Organic Yellow Onion            fresh vegetables
# 987247       Organic Baby Carrots  packaged vegetables fruits
# 987249       Organic Baby Spinach  packaged vegetables fruits
# 987250  Garnet Sweet Potato (Yam)            fresh vegetables
#
# [288775 rows x 2 columns]
# Department: meat seafood
# Number of products: 692
#                                              product_name  \
# 23      Air Chilled Organic Boneless Skinless Chicken ...
# 46               Boneless Skinless Chicken Breast Fillets
# 97                            Boneless Beef Sirloin Steak
# 176                                      Low Sodium Bacon
# 204                  Boneless And Skinless Chicken Breast
# ...                                                   ...
# 986977                  Organic Air Chilled Whole Chicken
# 987067  Natural Hickory Smoked Canadian Bacon Center C...
# 987068  All Natural Boneless & Skinless Chicken Breast...
# 987175                  Organic Air Chilled Whole Chicken
# 987179                      Organic Beef Uncured Hot Dogs
#
#                          aisle
# 23             poultry counter
# 46            packaged poultry
# 97                meat counter
# 176     hot dogs bacon sausage
# 204            poultry counter
# ...                        ...
# 986977         poultry counter
# 987067  hot dogs bacon sausage
# 987068        packaged poultry
# 987175         poultry counter
# 987179  hot dogs bacon sausage
#
# [21588 rows x 2 columns]
# Department: deli
# Number of products: 1069
#                                   product_name                   aisle
# 40                           Fresh Fruit Salad   prepared soups salads
# 101                      Mango Pineapple Salsa    fresh dips tapenades
# 179     Basil, Asiago & Pine Nut Pesto Ravioli          prepared meals
# 191                             Yuba Tofu Skin  tofu meat alternatives
# 192                          Organic Firm Tofu  tofu meat alternatives
# ...                                        ...                     ...
# 987153                    Spicy Avocado Hummus    fresh dips tapenades
# 987158                               Guacamole    fresh dips tapenades
# 987199                           Guacamole Dip    fresh dips tapenades
# 987204                         Original Hummus    fresh dips tapenades
# 987253                         Original Hummus    fresh dips tapenades
#
# [32008 rows x 2 columns]
# Department: frozen
# Number of products: 3127
#                                          product_name                    aisle
# 68                                   Pineapple Chunks           frozen produce
# 100            Teriyaki & Pineapple Chicken Meatballs             frozen meals
# 114     All Natural Boneless Skinless Chicken Breasts      frozen meat seafood
# 118                           Combination Pizza Rolls  frozen appetizers sides
# 135                    Organic Mini Homestyle Waffles         frozen breakfast
# ...                                               ...                      ...
# 987176                 Organic Ice Cream Vanilla Bean            ice cream ice
# 987180   Dairy Free Coconut Milk Frozen Dessert Minis            ice cream ice
# 987184                           Organic Mango Chunks           frozen produce
# 987210                            Bag of Large Lemons      frozen meat seafood
# 987215                              Vanilla Ice Cream            ice cream ice
#
# [68202 rows x 2 columns]
# Department: missing
# Number of products: 518
#                                          product_name    aisle
# 654                          Tomato Basil Bisque Soup  missing
# 1511      Cold Pressed Watermelon & Lemon Juice Blend  missing
# 1512                           Paleo Blueberry Muffin  missing
# 2126    Magic Tape Refillable Dispenser 3/4\" x 850\"  missing
# 4121                           Organic Poblano Pepper  missing
# ...                                               ...      ...
# 986067                       Oatneal Cookie Ice Cream  missing
# 986086    Dairy Free Unsweetened Almond Milk Beverage  missing
# 986103                Organic Asian Chopped Salad Kit  missing
# 986275                                      Lemon Bag  missing
# 986276      Organic Nondairy Strawberry Cashew Yogurt  missing
#
# [2289 rows x 2 columns]
# Department: other
# Number of products: 303
#                                              product_name  aisle
# 691            Coffee Mate French Vanilla Creamer Packets  other
# 1077                        SleepGels Nighttime Sleep Aid  other
# 1926                             Roasted Unsalted Almonds  other
# 1985                         Camilia, Single Liquid Doses  other
# 2127    Maximum Strength Original Paste Diaper Rash Oi...  other
# ...                                                   ...    ...
# 983992                           Roasted Unsalted Almonds  other
# 984112                           Boneless Pork Tenderloin  other
# 984515                              Roasted Almond Butter  other
# 984534            Light CocoWhip! Coconut Whipped Topping  other
# 986326                                   93/7 Ground Beef  other
#
# [1097 rows x 2 columns]

# %% [markdown]
# Looking at the results, products from `dairy eggs`, `meat seafood` `deli`, and some products from `missing` and `other` (would need to look at what exactly the product is since there was "Oatneal Cookie Ice Cream" in `missing` aisle which is a frozen item and "Boneless Pork Tenderloin" in `other` which is a `meat seafood` item) would be the departments that require refridgerant. Produce might not be a neccisity to be refridgerated as it can be stored at room temperature but only refridgerated to prolong shelf life so if there is a lot of demand for the produce, then it wouldn't be on the shelf for long but if there is low demand for it, then it might be better to not even have it as a selection so it might be a better idea to give the refridgerator space to the other aisles.

# %%
# Sanity check to see if aisles such as frozen produce are part of the frozen department or produce department
frozen_aisles = df[df['aisle'].str.contains('frozen', case=False)]['aisle'].unique()
print(frozen_aisles)
# Out:
# ['frozen produce' 'frozen meals' 'frozen meat seafood'
#  'frozen appetizers sides' 'frozen breakfast' 'frozen breads doughs'
#  'frozen vegan vegetarian' 'frozen pizza' 'frozen dessert' 'frozen juice']

# %%
frozen_department = df[df['aisle'].str.contains('frozen', case=False)]['department'].unique()
print(frozen_department)
# Out:
# ['frozen']

# %% [markdown]
# It is safe to assume that 100 products for the frozen products will be from the frozen department and maybe `missing` and `other` department.

# %% [markdown]
# ## 2. Product Selection

# %% [markdown]
# Now that EDA has been performed, the selection of products will be performed. The dataset will be randomly divided into a training and test set based on orders where 80% of orders will be the training data and 20% of orders used as test data.

# %%
# Creating a training and test 
# randomly select order ids
train_order_ids = df['order_id'].sample(n=int(df['order_id'].nunique()*.8), random_state=1)
# a boolean mask to show what orders are part of training or not
train_mask = df['order_id'].isin(train_order_ids)
# creating the training dataframe
train_set = df[train_mask]
train_set
# Out:
#         order_id  product_id                                   product_name  \
# 0              1       49302                               Bulgarian Yogurt
# 1              1       11109  Organic 4% Milk Fat Whole Milk Cottage Cheese
# 2              1       10246                          Organic Celery Hearts
# 3              1       49683                                 Cucumber Kirby
# 4              1       43633           Lightly Smoked Sardines in Olive Oil
# ...          ...         ...                                            ...
# 987254    100000       30169        Total 2% All Natural Plain Greek Yogurt
# 987255    100000       38734                           Wheat Sandwich Thins
# 987256    100000       36759         Unscented Long Lasting Stick Deodorant
# 987257    100000       37107                                   Ground Cumin
# 987258    100000       31506                         Extra Virgin Olive Oil
#
#         aisle_id                 aisle  department_id     department
# 0            120                yogurt             16     dairy eggs
# 1            108  other creams cheeses             16     dairy eggs
# 2             83      fresh vegetables              4        produce
# 3             83      fresh vegetables              4        produce
# 4             95   canned meat seafood             15   canned goods
# ...          ...                   ...            ...            ...
# 987254       120                yogurt             16     dairy eggs
# 987255       128  tortillas flat bread              3         bakery
# 987256        80            deodorants             11  personal care
# 987257       104     spices seasonings             13         pantry
# 987258        19         oils vinegars             13         pantry
#
# [647192 rows x 7 columns]

# %%
# test set is the data that were not part of the training mask 
test_set = df[~train_mask]
test_set
# Out:
#         order_id  product_id  \
# 17             3       33754
# 18             3       24838
# 19             3       17704
# 20             3       21903
# 21             3       17668
# ...          ...         ...
# 987239     99999       16953
# 987240     99999       36186
# 987241     99999       10034
# 987242     99999       44085
# 987243     99999        9558
#
#                                              product_name  aisle_id  \
# 17      Total 2% with Strawberry Lowfat Greek Strained...       120
# 18                                 Unsweetened Almondmilk        91
# 19                                                 Lemons       123
# 20                                   Organic Baby Spinach       123
# 21        Unsweetened Chocolate Almond Breeze Almond Milk        91
# ...                                                   ...       ...
# 987239                               Creamy Peanut Butter        88
# 987240                        Large Grade AA Organic Eggs        86
# 987241                Reduced Fat Mozarella String Cheese        21
# 987242                   Vanilla Light & Fit Greek Yogurt       120
# 987243               Non-Fat Vanilla Blended Greek Yogurt       120
#
#                              aisle  department_id  department
# 17                          yogurt             16  dairy eggs
# 18                 soy lactosefree             16  dairy eggs
# 19      packaged vegetables fruits              4     produce
# 20      packaged vegetables fruits              4     produce
# 21                 soy lactosefree             16  dairy eggs
# ...                            ...            ...         ...
# 987239                     spreads             13      pantry
# 987240                        eggs             16  dairy eggs
# 987241             packaged cheese             16  dairy eggs
# 987242                      yogurt             16  dairy eggs
# 987243                      yogurt             16  dairy eggs
#
# [340067 rows x 7 columns]

# %%
train_set.shape[0] + test_set.shape[0] == df.shape[0]
# Out:
# True

# %% [markdown]
# It is safe to assume that 100 products for the frozen products will be from the frozen department and maybe `missing` and `other` department.

# %%
# storing all frozen products into a variable
train_freezer = train_set[train_set['department']=='frozen']
train_freezer
test_freezer = test_set[test_set['department']=='frozen']
test_freezer
# Out:
#         order_id  product_id  \
# 100           11       30162
# 114           12       38050
# 118           12       29471
# 165           18       28934
# 216           23       13497
# ...          ...         ...
# 987011     99975       16351
# 987030     99977       49273
# 987082     99982        2102
# 987210     99996        9434
# 987215     99996       32691
#
#                                              product_name  aisle_id  \
# 100                Teriyaki & Pineapple Chicken Meatballs        38
# 114         All Natural Boneless Skinless Chicken Breasts        34
# 118                               Combination Pizza Rolls       129
# 165                               Frozen Broccoli Florets       116
# 216            Gluten and Dairy Free Sonoma Veggie Burger        42
# ...                                                   ...       ...
# 987011                   Chicken & Cilantro Mini  Wontons       129
# 987030  Light and Lean Quinoa Black Beans with Buttern...        38
# 987082                          Hash Browns Country Style        52
# 987210                                Bag of Large Lemons        34
# 987215                                  Vanilla Ice Cream        37
#
#                           aisle  department_id department
# 100                frozen meals              1     frozen
# 114         frozen meat seafood              1     frozen
# 118     frozen appetizers sides              1     frozen
# 165              frozen produce              1     frozen
# 216     frozen vegan vegetarian              1     frozen
# ...                         ...            ...        ...
# 987011  frozen appetizers sides              1     frozen
# 987030             frozen meals              1     frozen
# 987082         frozen breakfast              1     frozen
# 987210      frozen meat seafood              1     frozen
# 987215            ice cream ice              1     frozen
#
# [23114 rows x 7 columns]

# %%
# storing all fridge products into a variable
train_fridge = train_set[train_set['department'].isin(['dairy eggs', 'meat seafood', 'deli'])]
train_fridge
test_fridge = test_set[test_set['department'].isin(['dairy eggs', 'meat seafood', 'deli'])]
test_fridge
# Out:
#         order_id  product_id  \
# 17             3       33754
# 18             3       24838
# 21             3       17668
# 23             3       17461
# 73             9        2014
# ...          ...         ...
# 987213     99996       26900
# 987240     99999       36186
# 987241     99999       10034
# 987242     99999       44085
# 987243     99999        9558
#
#                                              product_name  aisle_id  \
# 17      Total 2% with Strawberry Lowfat Greek Strained...       120
# 18                                 Unsweetened Almondmilk        91
# 21        Unsweetened Chocolate Almond Breeze Almond Milk        91
# 23      Air Chilled Organic Boneless Skinless Chicken ...        35
# 73      Low Fat Kefir Cultured Milk Smoothie Lowfat Pr...       120
# ...                                                   ...       ...
# 987213                           USDA AA Extra Large Eggs        86
# 987240                        Large Grade AA Organic Eggs        86
# 987241                Reduced Fat Mozarella String Cheese        21
# 987242                   Vanilla Light & Fit Greek Yogurt       120
# 987243               Non-Fat Vanilla Blended Greek Yogurt       120
#
#                   aisle  department_id    department
# 17               yogurt             16    dairy eggs
# 18      soy lactosefree             16    dairy eggs
# 21      soy lactosefree             16    dairy eggs
# 23      poultry counter             12  meat seafood
# 73               yogurt             16    dairy eggs
# ...                 ...            ...           ...
# 987213             eggs             16    dairy eggs
# 987240             eggs             16    dairy eggs
# 987241  packaged cheese             16    dairy eggs
# 987242           yogurt             16    dairy eggs
# 987243           yogurt             16    dairy eggs
#
# [75351 rows x 7 columns]

# %%
# removing the freezer and fridge products from the train and test dataframe creating the dataframe for the 800 in aisle products
remove_index = train_freezer.index.union(train_fridge.index)
train_aisle = train_set.drop(remove_index)
remove_index2 = test_freezer.index.union(test_fridge.index)
test_aisle = test_set.drop(remove_index2)

# %%
# Sanity check
train_aisle
# Out:
#         order_id  product_id                            product_name  \
# 2              1       10246                   Organic Celery Hearts
# 3              1       49683                          Cucumber Kirby
# 4              1       43633    Lightly Smoked Sardines in Olive Oil
# 5              1       13176                  Bag of Organic Bananas
# 6              1       47209                    Organic Hass Avocado
# ...          ...         ...                                     ...
# 987252    100000       19508                          Corn Tortillas
# 987255    100000       38734                    Wheat Sandwich Thins
# 987256    100000       36759  Unscented Long Lasting Stick Deodorant
# 987257    100000       37107                            Ground Cumin
# 987258    100000       31506                  Extra Virgin Olive Oil
#
#         aisle_id                 aisle  department_id     department
# 2             83      fresh vegetables              4        produce
# 3             83      fresh vegetables              4        produce
# 4             95   canned meat seafood             15   canned goods
# 5             24          fresh fruits              4        produce
# 6             24          fresh fruits              4        produce
# ...          ...                   ...            ...            ...
# 987252       128  tortillas flat bread              3         bakery
# 987255       128  tortillas flat bread              3         bakery
# 987256        80            deodorants             11  personal care
# 987257       104     spices seasonings             13         pantry
# 987258        19         oils vinegars             13         pantry
#
# [459391 rows x 7 columns]

# %%
# Sanity Check
test_aisle
# Out:
#         order_id  product_id                              product_name  \
# 19             3       17704                                    Lemons
# 20             3       21903                      Organic Baby Spinach
# 22             3       46667                       Organic Ginger Root
# 24             3       32665  Organic Ezekiel 49 Bread Cinnamon Raisin
# 64             6       40462                                   Cleanse
# ...          ...         ...                                       ...
# 987235     99998        3178         Healthy Trinity, 3 in 1, Capsules
# 987236     99999        8424                            Broccoli Crown
# 987237     99999       22839                    Grainiac Organic Bread
# 987238     99999       40897                                      Kale
# 987239     99999       16953                      Creamy Peanut Butter
#
#         aisle_id                       aisle  department_id     department
# 19           123  packaged vegetables fruits              4        produce
# 20           123  packaged vegetables fruits              4        produce
# 22            83            fresh vegetables              4        produce
# 24           112                       bread              3         bakery
# 64            31                refrigerated              7      beverages
# ...          ...                         ...            ...            ...
# 987235        70                   digestion             11  personal care
# 987236        83            fresh vegetables              4        produce
# 987237       112                       bread              3         bakery
# 987238       123  packaged vegetables fruits              4        produce
# 987239        88                     spreads             13         pantry
#
# [241602 rows x 7 columns]

# %% [markdown]
# ### Method 2: Product Selection Proportional to Aisle Selection

# %% [markdown]
# This second method is to get a variety of items from each aisle proportional to the amount of orders for that aisle.

# %%
# finding the total amount of products ordered
train_size = train_aisle.shape[0]
train_size
# Out:
# 459391

# %%
# finding the amount of items ordered for each aisle
aisle_info=train_aisle.groupby('aisle').size().reset_index(name='count').sort_values(by='count', ascending=False)
aisle_info
# Out:
#                             aisle  count
# 46                   fresh fruits  71703
# 49               fresh vegetables  70817
# 74     packaged vegetables fruits  35881
# 99  water seltzer sparkling water  14954
# 24                 chips pretzels  14570
# ..                            ...    ...
# 90     specialty wines champagnes    166
# 2                baby accessories    165
# 3             baby bath body care    146
# 41                   eye ear care    144
# 8                          beauty    112
#
# [101 rows x 2 columns]

# %%
# Getting the percentage for later use
aisle_info['percentage']=aisle_info['count']/train_size*100
aisle_info
# Out:
#                             aisle  count  percentage
# 46                   fresh fruits  71703   15.608273
# 49               fresh vegetables  70817   15.415409
# 74     packaged vegetables fruits  35881    7.810558
# 99  water seltzer sparkling water  14954    3.255179
# 24                 chips pretzels  14570    3.171590
# ..                            ...    ...         ...
# 90     specialty wines champagnes    166    0.036135
# 2                baby accessories    165    0.035917
# 3             baby bath body care    146    0.031781
# 41                   eye ear care    144    0.031346
# 8                          beauty    112    0.024380
#
# [101 rows x 3 columns]

# %%
aisle_info
# Out:
#                             aisle  count  percentage
# 46                   fresh fruits  71703   15.608273
# 49               fresh vegetables  70817   15.415409
# 74     packaged vegetables fruits  35881    7.810558
# 99  water seltzer sparkling water  14954    3.255179
# 24                 chips pretzels  14570    3.171590
# ..                            ...    ...         ...
# 90     specialty wines champagnes    166    0.036135
# 2                baby accessories    165    0.035917
# 3             baby bath body care    146    0.031781
# 41                   eye ear care    144    0.031346
# 8                          beauty    112    0.024380
#
# [101 rows x 3 columns]

# %%
# Creating a mapping to add department into the aisle and count dataframe
train_aisle_mapping = train_aisle[['aisle', 'department']]
train_aisle_mapping = train_aisle_mapping.drop_duplicates()
train_aisle_mapping
# Out:
#                             aisle     department
# 2                fresh vegetables        produce
# 4             canned meat seafood   canned goods
# 5                    fresh fruits        produce
# 10              spices seasonings         pantry
# 11                  oils vinegars         pantry
# ...                           ...            ...
# 12585                   skin care  personal care
# 14099                eye ear care  personal care
# 14481                 white wines        alcohol
# 17168  specialty wines champagnes        alcohol
# 20969                      beauty  personal care
#
# [101 rows x 2 columns]

# %%
# Merge the 'aisle_count' dataframe with the 'department' column from 'train_aisle' based on the 'aisle' column
merged_df = aisle_info.merge(train_aisle_mapping, on='aisle', how='left')
merged_df
# Out:
#                              aisle  count  percentage     department
# 0                     fresh fruits  71703   15.608273        produce
# 1                 fresh vegetables  70817   15.415409        produce
# 2       packaged vegetables fruits  35881    7.810558        produce
# 3    water seltzer sparkling water  14954    3.255179      beverages
# 4                   chips pretzels  14570    3.171590         snacks
# ..                             ...    ...         ...            ...
# 96      specialty wines champagnes    166    0.036135        alcohol
# 97                baby accessories    165    0.035917         babies
# 98             baby bath body care    146    0.031781         babies
# 99                    eye ear care    144    0.031346  personal care
# 100                         beauty    112    0.024380  personal care
#
# [101 rows x 4 columns]

# %% [markdown]
# Now that the percentage of orders from each aisle has been calculated, the next step would be to see how many items this would translate to for the 800 product aisle.

# %%
merged_df['amount'] = round((merged_df['percentage']/100)*800)

# %%
merged_df
# Out:
#                              aisle  count  percentage     department  amount
# 0                     fresh fruits  71703   15.608273        produce   125.0
# 1                 fresh vegetables  70817   15.415409        produce   123.0
# 2       packaged vegetables fruits  35881    7.810558        produce    62.0
# 3    water seltzer sparkling water  14954    3.255179      beverages    26.0
# 4                   chips pretzels  14570    3.171590         snacks    25.0
# ..                             ...    ...         ...            ...     ...
# 96      specialty wines champagnes    166    0.036135        alcohol     0.0
# 97                baby accessories    165    0.035917         babies     0.0
# 98             baby bath body care    146    0.031781         babies     0.0
# 99                    eye ear care    144    0.031346  personal care     0.0
# 100                         beauty    112    0.024380  personal care     0.0
#
# [101 rows x 5 columns]

# %%
# Sanity Check to see if it equals 800
merged_df['amount'].sum()
# Out:
# 792.0

# %% [markdown]
# It did not equal 800 due to rounding so 8 more product needs to be added which will be the top 8 aisles that rounded to 0 (for variety and sicne this method is for variety)

# %%
rows = 800-merged_df['amount'].sum()
rows
# for when the sum of the amount is less than 800 (i.e. needs more product selected)
if rows > 0:
    for row in range(int(rows)):
        last_row = merged_df[merged_df['amount']==0].iloc[-1]
        print(last_row[0])
        # Changing the amount of the last row to 1
        merged_df.loc[merged_df['aisle'] == last_row[0], 'amount'] = 1
# for when the sum of the amount is more than 800 (i.e. needs less product selected)
elif rows < 0: 
    for row in range(int(rows)):
        last_row = merged_df[merged_df['amount']==0].iloc[-1]
        print(last_row[0])
        # Changing the amount of the last row to 1
        merged_df.loc[merged_df['aisle'] == last_row[0], 'amount'] = 0
# Out:
# beauty
# eye ear care
# baby bath body care
# baby accessories
# specialty wines champagnes
# kitchen supplies
# first aid
# shave needs

# %%
# Sanity Check
merged_df['amount'].sum()
# Out:
# 800.0

# %% [markdown]
# Now that the amount of products needed for each aisle has been determined, the next step would be to find the top X (X as in amount) product for each aisle as in method 1.

# %%
products_df=train_aisle.groupby('product_name').size().reset_index(name='count').sort_values(by='count', ascending=False)
products_df
# Out:
#                                    product_name  count
# 1805                                     Banana   9028
# 1689                     Bag of Organic Bananas   7152
# 15517                      Organic Strawberries   5233
# 13564                      Organic Baby Spinach   4797
# 14476                      Organic Hass Avocado   4282
# ...                                         ...    ...
# 11630                   Medium Black Bean Salsa      1
# 11638   Medium Diced Tomatoes with Green Chilis      1
# 11641                 Medium Fire Roasted Salsa      1
# 11642        Medium Fire Roasted Tatemada Salsa      1
# 24033  with a Splash of Pineapple Coconut Water      1
#
# [24034 rows x 2 columns]

# %%
product_mapping = train_aisle[['product_id', 'product_name', 'aisle_id', 'aisle', 'department_id', 'department']]

# %%
product_mapping = product_mapping.drop_duplicates(subset='product_name')

# %%
# products_df.set_index('product_name')

# %%
merged_df2 = products_df.merge(product_mapping, on='product_name', how='left')
merged_df2
# Out:
#                                    product_name  count  product_id  aisle_id  \
# 0                                        Banana   9028       24852        24
# 1                        Bag of Organic Bananas   7152       13176        24
# 2                          Organic Strawberries   5233       21137        24
# 3                          Organic Baby Spinach   4797       21903       123
# 4                          Organic Hass Avocado   4282       47209        24
# ...                                         ...    ...         ...       ...
# 24029                   Medium Black Bean Salsa      1       49450        51
# 24030   Medium Diced Tomatoes with Green Chilis      1       26934        81
# 24031                 Medium Fire Roasted Salsa      1       23242        51
# 24032        Medium Fire Roasted Tatemada Salsa      1       18640        51
# 24033  with a Splash of Pineapple Coconut Water      1        2987        98
#
#                             aisle  department_id    department
# 0                    fresh fruits              4       produce
# 1                    fresh fruits              4       produce
# 2                    fresh fruits              4       produce
# 3      packaged vegetables fruits              4       produce
# 4                    fresh fruits              4       produce
# ...                           ...            ...           ...
# 24029      preserved dips spreads             13        pantry
# 24030    canned jarred vegetables             15  canned goods
# 24031      preserved dips spreads             13        pantry
# 24032      preserved dips spreads             13        pantry
# 24033               juice nectars              7     beverages
#
# [24034 rows x 7 columns]

# %%
merged_df
# Out:
#                              aisle  count  percentage     department  amount
# 0                     fresh fruits  71703   15.608273        produce   125.0
# 1                 fresh vegetables  70817   15.415409        produce   123.0
# 2       packaged vegetables fruits  35881    7.810558        produce    62.0
# 3    water seltzer sparkling water  14954    3.255179      beverages    26.0
# 4                   chips pretzels  14570    3.171590         snacks    25.0
# ..                             ...    ...         ...            ...     ...
# 96      specialty wines champagnes    166    0.036135        alcohol     1.0
# 97                baby accessories    165    0.035917         babies     1.0
# 98             baby bath body care    146    0.031781         babies     1.0
# 99                    eye ear care    144    0.031346  personal care     1.0
# 100                         beauty    112    0.024380  personal care     1.0
#
# [101 rows x 5 columns]

# %%
# Selecting the 800 items for the aisle
result_df = pd.DataFrame()
for index, row in merged_df.iterrows():
    aisle_name = row['aisle']
    amount = int(row['amount'])
    display(merged_df2[merged_df2['aisle']==aisle_name].head(amount))
    result_df = pd.concat([result_df, merged_df2[merged_df2['aisle']==aisle_name].head(amount)])
result_df
# Out:
#                    product_name  count  product_id  aisle_id         aisle  \
# 0                        Banana   9028       24852        24  fresh fruits
# 1        Bag of Organic Bananas   7152       13176        24  fresh fruits
# 2          Organic Strawberries   5233       21137        24  fresh fruits
# 4          Organic Hass Avocado   4282       47209        24  fresh fruits
# 5               Organic Avocado   3493       47766        24  fresh fruits
# ...                         ...    ...         ...       ...           ...
# 2346           Organic Honeydew     31       17123        24  fresh fruits
# 2384  Organic Lady Alice Apples     31       27625        24  fresh fruits
# 2466             Braeburn Apple     29       13997        24  fresh fruits
# 2674           Small Cantaloupe     27       19086        24  fresh fruits
# 2754          Organic Mandarins     26       14966        24  fresh fruits
#
#       department_id department
# 0                 4    produce
# 1                 4    produce
# 2                 4    produce
# 4                 4    produce
# 5                 4    produce
# ...             ...        ...
# 2346              4    produce
# 2384              4    produce
# 2466              4    produce
# 2674              4    produce
# 2754              4    produce
#
# [125 rows x 7 columns]
#                       product_name  count  product_id  aisle_id  \
# 10            Organic Yellow Onion   2250       22935        83
# 11                  Organic Garlic   2239       24964        83
# 12                Organic Zucchini   2196       45007        83
# 14                  Cucumber Kirby   1936       49683        83
# 17                Organic Cucumber   1744       30391        83
# ..                             ...    ...         ...       ...
# 560  Organic Whole White Mushrooms    122       41540        83
# 576         Organic Broccoli Crown    119       13852        83
# 602                Heirloom Tomato    115       25647        83
# 633        Organic Cherry Tomatoes    110       22312        83
# 637                Russet Potatoes    109       26882        83
#
#                 aisle  department_id department
# 10   fresh vegetables              4    produce
# 11   fresh vegetables              4    produce
# 12   fresh vegetables              4    produce
# 14   fresh vegetables              4    produce
# 17   fresh vegetables              4    produce
# ..                ...            ...        ...
# 560  fresh vegetables              4    produce
# 576  fresh vegetables              4    produce
# 602  fresh vegetables              4    produce
# 633  fresh vegetables              4    produce
# 637  fresh vegetables              4    produce
#
# [123 rows x 7 columns]
#                   product_name  count  product_id  aisle_id  \
# 3         Organic Baby Spinach   4797       21903       123
# 8          Organic Raspberries   2765       27966       123
# 13         Organic Blueberries   1949       39275       123
# 16      Organic Grape Tomatoes   1757       40706       123
# 20         Seedless Red Grapes   1630        4920       123
# ..                         ...    ...         ...       ...
# 871                 Spring Mix     83       47145       123
# 872   Organic Biologique Limes     83       18159       123
# 900  Cut & Peeled Baby Carrots     80       10613       123
# 901           Baby Cut Carrots     80       48299       123
# 939             Chopped Onions     78       25230       123
#
#                           aisle  department_id department
# 3    packaged vegetables fruits              4    produce
# 8    packaged vegetables fruits              4    produce
# 13   packaged vegetables fruits              4    produce
# 16   packaged vegetables fruits              4    produce
# 20   packaged vegetables fruits              4    produce
# ..                          ...            ...        ...
# 871  packaged vegetables fruits              4    produce
# 872  packaged vegetables fruits              4    produce
# 900  packaged vegetables fruits              4    produce
# 901  packaged vegetables fruits              4    produce
# 939  packaged vegetables fruits              4    produce
#
# [62 rows x 7 columns]
#                             product_name  count  product_id  aisle_id  \
# 31            Sparkling Water Grapefruit   1457       44632       115
# 54                          Spring Water    900       19660       115
# 55                  Lime Sparkling Water    882       35221       115
# 63       Sparkling Natural Mineral Water    801       33198       115
# 76       Italian Sparkling Mineral Water    636        5479       115
# 80                 Sparkling Lemon Water    612       21709       115
# 94                  Pure Sparkling Water    507       14947       115
# 130  Peach Pear Flavored Sparkling Water    395       26620       115
# 146           Electrolyte Enhanced Water    367       26165       115
# 164                Sparkling Water Berry    335       20119       115
# 173                 Natural Spring Water    324        8859       115
# 189              Sparkling Mineral Water    300       43154       115
# 199               Orange Sparkling Water    282       49520       115
# 230           Grapefruit Sparkling Water    249       47977       115
# 250                      Distilled Water    234       23288       115
# 251                                Water    232       25466       115
# 298               Natural Artesian Water    205       14233       115
# 299  Blackberry Cucumber Sparkling Water    205       39947       115
# 331                Natural Artisan Water    188        1194       115
# 340                  Alpine Spring Water    186       27325       115
# 341       Cran Raspberry Sparkling Water    185       49191       115
# 344                      Sparkling Water    185        5258       115
# 375                       Purified Water    174       15424       115
# 416          Kiwi Sandia Sparkling Water    159       12576       115
# 418                Lemon Sparkling Water    157       36316       115
# 439                           Smartwater    152       21386       115
#
#                              aisle  department_id department
# 31   water seltzer sparkling water              7  beverages
# 54   water seltzer sparkling water              7  beverages
# 55   water seltzer sparkling water              7  beverages
# 63   water seltzer sparkling water              7  beverages
# 76   water seltzer sparkling water              7  beverages
# 80   water seltzer sparkling water              7  beverages
# 94   water seltzer sparkling water              7  beverages
# 130  water seltzer sparkling water              7  beverages
# 146  water seltzer sparkling water              7  beverages
# 164  water seltzer sparkling water              7  beverages
# 173  water seltzer sparkling water              7  beverages
# 189  water seltzer sparkling water              7  beverages
# 199  water seltzer sparkling water              7  beverages
# 230  water seltzer sparkling water              7  beverages
# 250  water seltzer sparkling water              7  beverages
# 251  water seltzer sparkling water              7  beverages
# 298  water seltzer sparkling water              7  beverages
# 299  water seltzer sparkling water              7  beverages
# 331  water seltzer sparkling water              7  beverages
# 340  water seltzer sparkling water              7  beverages
# 341  water seltzer sparkling water              7  beverages
# 344  water seltzer sparkling water              7  beverages
# 375  water seltzer sparkling water              7  beverages
# 416  water seltzer sparkling water              7  beverages
# 418  water seltzer sparkling water              7  beverages
# 439  water seltzer sparkling water              7  beverages
#                                           product_name  count  product_id  \
# 90                Lightly Salted Baked Snap Pea Crisps    547       13870
# 150                                Sea Salt Pita Chips    351       31040
# 157  Pretzel Crisps Original Deli Style Pretzel Cra...    341       21376
# 184                    Sea Salt & Vinegar Potato Chips    308       40709
# 219                   Organic Blue Corn Tortilla Chips    267       13380
# 229                              Sea Salt Potato Chips    250       18288
# 233  Aged White Cheddar Baked Rice & Corn Puffs Glu...    248       24841
# 248                            Pita Chips Simply Naked    236       25824
# 305                             Organic Tortilla Chips    202       35561
# 349                                         Corn Chips    183       11576
# 374                      Original Real Vegetable Chips    174       20580
# 376                        Sweet Potato Tortilla Chips    174        8555
# 380                          Multigrain Tortilla Chips    172       46692
# 405                             Scoops! Tortilla Chips    162        7644
# 423                        Thin & Light Tortilla Chips    157       17835
# 431                                       Veggie Chips    154       14633
# 458              Dark Chocolate Pretzels with Sea Salt    147       19006
# 460                     Backyard Barbeque Potato Chips    146        6489
# 464                        Salt & Pepper Krinkle Chips    144       46049
# 505                      Thick & Crispy Tortilla Chips    132       46226
# 542                                     Plantain Chips    124       16589
# 578                              Jalapeno Potato Chips    119       47866
# 587                              Multigrain Pita Chips    118       14858
# 596                    Sour Cream & Onion Potato Chips    116       23645
# 615           Original Restaurant Style Tortilla Chips    113       47357
#
#      aisle_id           aisle  department_id department
# 90        107  chips pretzels             19     snacks
# 150       107  chips pretzels             19     snacks
# 157       107  chips pretzels             19     snacks
# 184       107  chips pretzels             19     snacks
# 219       107  chips pretzels             19     snacks
# 229       107  chips pretzels             19     snacks
# 233       107  chips pretzels             19     snacks
# 248       107  chips pretzels             19     snacks
# 305       107  chips pretzels             19     snacks
# 349       107  chips pretzels             19     snacks
# 374       107  chips pretzels             19     snacks
# 376       107  chips pretzels             19     snacks
# 380       107  chips pretzels             19     snacks
# 405       107  chips pretzels             19     snacks
# 423       107  chips pretzels             19     snacks
# 431       107  chips pretzels             19     snacks
# 458       107  chips pretzels             19     snacks
# 460       107  chips pretzels             19     snacks
# 464       107  chips pretzels             19     snacks
# 505       107  chips pretzels             19     snacks
# 542       107  chips pretzels             19     snacks
# 578       107  chips pretzels             19     snacks
# 587       107  chips pretzels             19     snacks
# 596       107  chips pretzels             19     snacks
# 615       107  chips pretzels             19     snacks
#                                        product_name  count  product_id  \
# 40                           100% Whole Wheat Bread   1177        5077
# 103              Organic Bread with 21 Whole Grains    478       18362
# 143  Ezekiel 4:9 Bread Organic Sprouted Whole Grain    371       18027
# 154                                 Sourdough Bread    343       21267
# 241           Organic Honey Sweet Whole Wheat Bread    243        3896
# 244              Organic 21 Grain Thin Sliced Bread    240       45123
# 247                         Organic Good Seed Bread    237        2855
# 264                               Whole Wheat Bread    226       13517
# 274                       Organic Whole Wheat Bread    221       48628
# 381                       Gluten Free 7 Grain Bread    172       45948
# 440                      California Sourdough Bread    151       23233
# 465                Gluten Free White Sandwich Bread    144       39097
# 473                             Classic White Bread    141       35383
# 480                           Cinnamon Raisin Bread    140        8467
# 503                                  Sweet Baguette    133       14467
# 538                               Honey Wheat Bread    125       45064
# 553                              Sourdough Baguette    123       20583
# 565                            White Sandwich Bread    121       21497
# 600                            Multigrain Oat Bread    115       12756
# 604                      Sprouted Multi-Grain Bread    115       36606
#
#      aisle_id  aisle  department_id department
# 40        112  bread              3     bakery
# 103       112  bread              3     bakery
# 143       112  bread              3     bakery
# 154       112  bread              3     bakery
# 241       112  bread              3     bakery
# 244       112  bread              3     bakery
# 247       112  bread              3     bakery
# 264       112  bread              3     bakery
# 274       112  bread              3     bakery
# 381       112  bread              3     bakery
# 440       112  bread              3     bakery
# 465       112  bread              3     bakery
# 473       112  bread              3     bakery
# 480       112  bread              3     bakery
# 503       112  bread              3     bakery
# 538       112  bread              3     bakery
# 553       112  bread              3     bakery
# 565       112  bread              3     bakery
# 600       112  bread              3     bakery
# 604       112  bread              3     bakery
#                                           product_name  count  product_id  \
# 73                              100% Raw Coconut Water    702        3957
# 106                              Original Orange Juice    469       25146
# 114                     Organic Raw Kombucha Gingerade    437       30776
# 134                                           Lemonade    387       41290
# 151         Original No Pulp 100% Florida Orange Juice    349       31683
# 155                             Trilogy Kombucha Drink    342       45603
# 187                                       Orange Juice    305       34050
# 323               Synergy Organic Kombucha Gingerberry    192       48559
# 338      No Pulp Calcium & Vitamin D Pure Orange Juice    187        6631
# 343                             Pulp Free Orange Juice    185       39108
# 360  Juice Beverage, Cold Pressed, Kale Apple Ginge...    180       13292
# 379                                        Apple Juice    173       38200
# 449                   Organic Raw Multigreen Kobmbucha    150        9421
# 471      Florida Orange Juice With Calcium & Vitamin D    141        8087
# 484         Organic & Raw Strawberry Serenity Kombucha    139        6287
# 487             Synergy Organic & Raw Cosmic Cranberry    137        8736
# 497                   Enlightened Organic Raw Kombucha    135       19894
# 543                      Freshly Squeezed Orange Juice    124       36127
# 624                                 Raspberry Lemonade    112       43967
# 678                Organic Fresh Squeezed Orange Juice    104       32578
#
#      aisle_id         aisle  department_id department
# 73         31  refrigerated              7  beverages
# 106        31  refrigerated              7  beverages
# 114        31  refrigerated              7  beverages
# 134        31  refrigerated              7  beverages
# 151        31  refrigerated              7  beverages
# 155        31  refrigerated              7  beverages
# 187        31  refrigerated              7  beverages
# 323        31  refrigerated              7  beverages
# 338        31  refrigerated              7  beverages
# 343        31  refrigerated              7  beverages
# 360        31  refrigerated              7  beverages
# 379        31  refrigerated              7  beverages
# 449        31  refrigerated              7  beverages
# 471        31  refrigerated              7  beverages
# 484        31  refrigerated              7  beverages
# 487        31  refrigerated              7  beverages
# 497        31  refrigerated              7  beverages
# 543        31  refrigerated              7  beverages
# 624        31  refrigerated              7  beverages
# 678        31  refrigerated              7  beverages
#                                           product_name  count  product_id  \
# 209                  Kids Organic Chocolate Chip ZBars    273       44560
# 258  Gluten Free Dark Chocolate Chunk Chewy with a ...    228        5322
# 390  Peanut Butter Chocolate Chip Fruit & Nut Food Bar    169       23579
# 403                   Oats & Honey Gluten Free Granola    163       17224
# 408        ZBar Organic Chocolate Brownie Energy Snack    160       16254
# 417                     Apple Pie Fruit & Nut Food Bar    158       33716
# 462          Organic Chocolate Chip Chewy Granola Bars    145       14778
# 463  Gluten Free Peanut Butter Dark Chocolate Chewy...    145       38656
# 501                      Iced Oatmeal Cookie Kid Z Bar    133       25197
# 586                         Cherry Pie Fruit & Nut Bar    118       26629
# 599                                   Coconut Chia Bar    115       23291
# 625                                  Peanut Butter Bar    111       10753
# 648                               Blueberry Muffin Bar    108        5250
# 667                   Crunchy Peanut Butter Energy Bar    106       20876
# 683                               Peanut Butter Cookie    104       47717
# 691                                 Chocolate Sea Salt    102       34137
# 704                                  Coconut Cream Pie    101       22227
#
#      aisle_id                aisle  department_id department
# 209         3  energy granola bars             19     snacks
# 258         3  energy granola bars             19     snacks
# 390         3  energy granola bars             19     snacks
# 403         3  energy granola bars             19     snacks
# 408         3  energy granola bars             19     snacks
# 417         3  energy granola bars             19     snacks
# 462         3  energy granola bars             19     snacks
# 463         3  energy granola bars             19     snacks
# 501         3  energy granola bars             19     snacks
# 586         3  energy granola bars             19     snacks
# 599         3  energy granola bars             19     snacks
# 625         3  energy granola bars             19     snacks
# 648         3  energy granola bars             19     snacks
# 667         3  energy granola bars             19     snacks
# 683         3  energy granola bars             19     snacks
# 691         3  energy granola bars             19     snacks
# 704         3  energy granola bars             19     snacks
#                                           product_name  count  product_id  \
# 214               Crackers Cheddar Bunnies Snack Packs    269       39561
# 239                  Hint Of Sea Salt Almond Nut Thins    243       34262
# 246                     Cheddar Bunnies Snack Crackers    238       22474
# 348                   Almond Nut & Rice Cracker Snacks    184        2091
# 391  Organic Wheat-Free & Gluten-Free Original Crac...    167       40268
# 393            Organic Lightly Salted Brown Rice Cakes    166       24810
# 415       Organic Mini Sandwich Crackers Peanut Butter    159       11352
# 437              Original Black Box Tablewater Cracker    152        8479
# 444                      Organic Wheat Square Crackers    151       48595
# 448              Goldfish Cheddar Baked Snack Crackers    150       17616
# 467                             Crispy Wheat, Crackers    142       21009
# 489                                   Saltine Crackers    137       18382
# 508                       Crackers Harvest Whole Wheat    132       21614
# 563                 Organic Stoneground Wheat Crackers    121       28597
# 606      6 OZ LA PANZANELLA CROSTINI ORIGINAL CRACKERS    115       12572
# 623  Goldfish Cheddar Baked Snack Crackers Multi Packs    112       33894
#
#      aisle_id     aisle  department_id department
# 214        78  crackers             19     snacks
# 239        78  crackers             19     snacks
# 246        78  crackers             19     snacks
# 348        78  crackers             19     snacks
# 391        78  crackers             19     snacks
# 393        78  crackers             19     snacks
# 415        78  crackers             19     snacks
# 437        78  crackers             19     snacks
# 444        78  crackers             19     snacks
# 448        78  crackers             19     snacks
# 467        78  crackers             19     snacks
# 489        78  crackers             19     snacks
# 508        78  crackers             19     snacks
# 563        78  crackers             19     snacks
# 606        78  crackers             19     snacks
# 623        78  crackers             19     snacks
#                                           product_name  count  product_id  \
# 288   Baby Food Stage 2 Blueberry Pear & Purple Carrot    211       43875
# 292              Spinach Peas & Pear Stage 2 Baby Food    207       34134
# 438                 Broccoli & Apple Stage 2 Baby Food    152        3020
# 468           Organic Mixed Berry Yogurt & Fruit Snack    142       21162
# 477  Stage 1 Apples Sweet Potatoes Pumpkin & Bluebe...    140        5491
# 539              Gluten Free SpongeBob Spinach Littles    124        2611
# 547               Kids Sensible Foods Broccoli Littles    124       49215
# 552     Organic Pears, Peas and Broccoli Puree Stage 1    123       49044
# 566            Organic Strawberry Yogurt & Fruit Snack    121       18176
# 631                   Baby Food Stage 2 Pumpkin Banana    111       14211
# 658         Peach,  Apricot & Banana Stage 2 Baby Food    107        5114
# 715                 Apple and Carrot Stage 2 Baby Food     99       47888
# 725       Organic Whole Grain Oatmeal Cereal Baby Food     97        1202
# 761                     Pear & Mango Stage 2 Baby Food     93       38192
# 769      Happy Baby Spinach, Mango, and Pear Baby Food     92       14491
#
#      aisle_id              aisle  department_id department
# 288        92  baby food formula             18     babies
# 292        92  baby food formula             18     babies
# 438        92  baby food formula             18     babies
# 468        92  baby food formula             18     babies
# 477        92  baby food formula             18     babies
# 539        92  baby food formula             18     babies
# 547        92  baby food formula             18     babies
# 552        92  baby food formula             18     babies
# 566        92  baby food formula             18     babies
# 631        92  baby food formula             18     babies
# 658        92  baby food formula             18     babies
# 715        92  baby food formula             18     babies
# 725        92  baby food formula             18     babies
# 761        92  baby food formula             18     babies
# 769        92  baby food formula             18     babies
#                                    product_name  count  product_id  aisle_id  \
# 30                             Organic Cilantro   1463       31717        16
# 39                Organic Italian Parsley Bunch   1193       34126        16
# 52                             Bunched Cilantro    949       28842        16
# 88                                Organic Basil    555       43789        16
# 127                               Organic Thyme    404       39812        16
# 137                                Organic Mint    383       13984        16
# 165                                Organic Dill    334       39984        16
# 210                         Flat Parsley, Bunch    272       42625        16
# 242                         Organic Fresh Basil    242        1025        16
# 286                                        Mint    213        4086        16
# 321                            Organic Rosemary    194       15261        16
# 383  Parsley, Italian (Flat), New England Grown    171        1529        16
# 483                                       Basil    139        8955        16
#
#            aisle  department_id department
# 30   fresh herbs              4    produce
# 39   fresh herbs              4    produce
# 52   fresh herbs              4    produce
# 88   fresh herbs              4    produce
# 127  fresh herbs              4    produce
# 137  fresh herbs              4    produce
# 165  fresh herbs              4    produce
# 210  fresh herbs              4    produce
# 242  fresh herbs              4    produce
# 286  fresh herbs              4    produce
# 321  fresh herbs              4    produce
# 383  fresh herbs              4    produce
# 483  fresh herbs              4    produce
#                              product_name  count  product_id  aisle_id  \
# 92                     Honey Nut Cheerios    533       41844       121
# 167                    Raisin Bran Cereal    333        6187       121
# 276                                Cereal    219       20955       121
# 315        Organic Cinnamon Crunch Cereal    196       31433       121
# 402                       Cheerios Cereal    163         365       121
# 502                  Peanut Butter Cereal    133          34       121
# 558                Whole Grain Oat Cereal    122        4137       121
# 574               Original Puffins Cereal    119       31640       121
# 588   Frosted Mini-Wheats Original Cereal    118       43409       121
# 610  Original Multigrain Spoonfuls Cereal    115       39216       121
# 645      Panda Puffs Peanut Butter Cereal    108        4792       121
# 688          Organic Honey Nut O's Cereal    103       26177       121
# 709                 GOLEAN Crunch! Cereal    100       27663       121
#
#       aisle  department_id department
# 92   cereal             14  breakfast
# 167  cereal             14  breakfast
# 276  cereal             14  breakfast
# 315  cereal             14  breakfast
# 402  cereal             14  breakfast
# 502  cereal             14  breakfast
# 558  cereal             14  breakfast
# 574  cereal             14  breakfast
# 588  cereal             14  breakfast
# 610  cereal             14  breakfast
# 645  cereal             14  breakfast
# 688  cereal             14  breakfast
# 709  cereal             14  breakfast
#                                     product_name  count  product_id  aisle_id  \
# 158             Organic Low Sodium Chicken Broth    340       45535        69
# 202             Organic Free Range Chicken Broth    281       46720        69
# 237                      Organic Vegetable Broth    244        9092        69
# 266           Organic Low Sodium Vegetable Broth    225       18479        69
# 270                        Organic Chicken Broth    223        1999        69
# 279                        Organic Chicken Stock    218        5769        69
# 425  Organic Free Range Low Sodium Chicken Broth    156       18880        69
# 441                   Organic Chicken Bone Broth    151       14129        69
# 493                  Organic Chicken Noodle Soup    136       46900        69
# 506     Organic Low Sodium Chicken Cooking Stock    132       11136        69
# 519                           Organic Beef Broth    130       16823        69
# 546                   Organic Creamy Tomato Soup    124       21417        69
#
#                    aisle  department_id    department
# 158  soup broth bouillon             15  canned goods
# 202  soup broth bouillon             15  canned goods
# 237  soup broth bouillon             15  canned goods
# 266  soup broth bouillon             15  canned goods
# 270  soup broth bouillon             15  canned goods
# 279  soup broth bouillon             15  canned goods
# 425  soup broth bouillon             15  canned goods
# 441  soup broth bouillon             15  canned goods
# 493  soup broth bouillon             15  canned goods
# 506  soup broth bouillon             15  canned goods
# 519  soup broth bouillon             15  canned goods
# 546  soup broth bouillon             15  canned goods
#                                           product_name  count  product_id  \
# 149                                 Pure Coconut Water    354        2966
# 272                      Natural Premium Coconut Water    223       42719
# 281                                Organic Apple Juice    217       18811
# 317               Orange Calcium & Vitamin D Pulp Free    195       19173
# 326                               Organic Orange Juice    191       30639
# 367  No Pulp Calcium & Vitamin D Pure Premium 100% ...    178       38890
# 387                                   Organic Lemonade    169       26317
# 512                          Organic Apple Juice Boxes    131       13113
# 528              Organic Super Fruit Punch Juice Drink    128       24850
# 589                                      Coconut Water    117       14715
# 607                         Organic Orange Fruit Juice    115       36036
#
#      aisle_id          aisle  department_id department
# 149        98  juice nectars              7  beverages
# 272        98  juice nectars              7  beverages
# 281        98  juice nectars              7  beverages
# 317        98  juice nectars              7  beverages
# 326        98  juice nectars              7  beverages
# 367        98  juice nectars              7  beverages
# 387        98  juice nectars              7  beverages
# 512        98  juice nectars              7  beverages
# 528        98  juice nectars              7  beverages
# 589        98  juice nectars              7  beverages
# 607        98  juice nectars              7  beverages
#                                   product_name  count  product_id  aisle_id  \
# 222                          Light Brown Sugar    265       23537        17
# 296                    Organic Vanilla Extract    206        7500        17
# 324                                 Cane Sugar    191       49533        17
# 369                          100% Pure Pumpkin    176       22142        17
# 426         Premium Pure Cane Granulated Sugar    155       27243        17
# 433       Organic Unbleached All-Purpose Flour    153       23516        17
# 446                           Pure Baking Soda    150       23405        17
# 679  Semi-Sweet Chocolate Premium Baking Chips    104        8671        17
# 701               Unbleached All-Purpose Flour    101       35855        17
# 702                 Pure Granulated Cane Sugar    101         397        17
# 719                         Organic Cane Sugar     98       34551        17
#
#                   aisle  department_id department
# 222  baking ingredients             13     pantry
# 296  baking ingredients             13     pantry
# 324  baking ingredients             13     pantry
# 369  baking ingredients             13     pantry
# 426  baking ingredients             13     pantry
# 433  baking ingredients             13     pantry
# 446  baking ingredients             13     pantry
# 679  baking ingredients             13     pantry
# 701  baking ingredients             13     pantry
# 702  baking ingredients             13     pantry
# 719  baking ingredients             13     pantry
#                                       product_name  count  product_id  \
# 105                         Organic Diced Tomatoes    469         890
# 141                           Organic Tomato Paste    372        7021
# 183                                 Diced Tomatoes    309        8670
# 191                           Organic Tomato Sauce    296       44449
# 197  Organic Whole Kernel Sweet Corn No Salt Added    283        3376
# 204                               Crushed Tomatoes    279       11408
# 231                                   Tomato Sauce    249       22395
# 269           Organic No Salt Added Diced Tomatoes    223        5373
# 430          Organic Crushed Fire Roasted Tomatoes    154       41544
# 511                        Mild Diced Green Chiles    131       20520
# 513       Fresh Cut Golden Sweet Whole Kernel Corn    131       25544
#
#      aisle_id                     aisle  department_id    department
# 105        81  canned jarred vegetables             15  canned goods
# 141        81  canned jarred vegetables             15  canned goods
# 183        81  canned jarred vegetables             15  canned goods
# 191        81  canned jarred vegetables             15  canned goods
# 197        81  canned jarred vegetables             15  canned goods
# 204        81  canned jarred vegetables             15  canned goods
# 231        81  canned jarred vegetables             15  canned goods
# 269        81  canned jarred vegetables             15  canned goods
# 430        81  canned jarred vegetables             15  canned goods
# 511        81  canned jarred vegetables             15  canned goods
# 513        81  canned jarred vegetables             15  canned goods
#                          product_name  count  product_id  aisle_id  \
# 109                              Soda    456         196        77
# 181                  Fridge Pack Cola    310       10957        77
# 245                        Ginger Ale    239       12916        77
# 284                              Cola    216       47141        77
# 386                      Coke Classic    170       16696        77
# 452                         Root Beer    149       40910        77
# 486                    Arancita Rossa    137        4138        77
# 514                   Cola Soft Drink    130       10032        77
# 555  Diet Ginger Ale All Natural Soda    123       18564        77
# 580           Canned Aranciata Orange    119       44375        77
# 581                         Club Soda    118       24759        77
#
#            aisle  department_id department
# 109  soft drinks              7  beverages
# 181  soft drinks              7  beverages
# 245  soft drinks              7  beverages
# 284  soft drinks              7  beverages
# 386  soft drinks              7  beverages
# 452  soft drinks              7  beverages
# 486  soft drinks              7  beverages
# 514  soft drinks              7  beverages
# 555  soft drinks              7  beverages
# 580  soft drinks              7  beverages
# 581  soft drinks              7  beverages
#                           product_name  count  product_id  aisle_id  \
# 223              Organic Whole Cashews    262       35140       117
# 224  Organic Thompson Seedless Raisins    259        5134       117
# 235                      Whole Almonds    245        7503       117
# 283              Organic Medjool Dates    216       20734       117
# 291                    Chopped Walnuts    209       12845       117
# 335             Walnut Halves & Pieces    187       16521       117
# 435           Roasted & Salted Almonds    153       29926       117
# 461                            Raisins    145       14901       117
# 482             Roasted Salted Cashews    139       13819       117
# 516                       Pitted Dates    130       34590       117
# 549        Dried Sweetened Cranberries    123         248       117
#
#                       aisle  department_id department
# 223  nuts seeds dried fruit             19     snacks
# 224  nuts seeds dried fruit             19     snacks
# 235  nuts seeds dried fruit             19     snacks
# 283  nuts seeds dried fruit             19     snacks
# 291  nuts seeds dried fruit             19     snacks
# 335  nuts seeds dried fruit             19     snacks
# 435  nuts seeds dried fruit             19     snacks
# 461  nuts seeds dried fruit             19     snacks
# 482  nuts seeds dried fruit             19     snacks
# 516  nuts seeds dried fruit             19     snacks
# 549  nuts seeds dried fruit             19     snacks
#                                     product_name  count  product_id  aisle_id  \
# 59                           Organic Black Beans    849       27156        59
# 78                        Organic Garbanzo Beans    632       42768        59
# 84                     No Salt Added Black Beans    590       28849        59
# 172                                  Black Beans    324       35042        59
# 236                          Organic Pinto Beans    244       49175        59
# 359                     Organic Cannellini Beans    180       16145        59
# 548  Cannellini White Kidney Beans No Salt Added    123       26668        59
# 550                    Traditional Refried Beans    123        5994        59
# 584                    Black Beans No Salt Added    118       27683        59
# 628         Organic Garbanzo Beans No Salt Added    111       35750        59
#
#                   aisle  department_id    department
# 59   canned meals beans             15  canned goods
# 78   canned meals beans             15  canned goods
# 84   canned meals beans             15  canned goods
# 172  canned meals beans             15  canned goods
# 236  canned meals beans             15  canned goods
# 359  canned meals beans             15  canned goods
# 548  canned meals beans             15  canned goods
# 550  canned meals beans             15  canned goods
# 584  canned meals beans             15  canned goods
# 628  canned meals beans             15  canned goods
#                                            product_name  count  product_id  \
# 211                Almonds & Sea Salt in Dark Chocolate    272       38164
# 287           Organic Dark Chocolate Peanut Butter Cups    212       46616
# 561   Dark with 70% Cacao Content Organic Chocolate Bar    122       43192
# 572           Organic Milk Chocolate Peanut Butter Cups    119       29077
# 617                Organic 85% Cacao Dark Chocolate Bar    113        2480
# 689             Bar, Toffee & Almonds in Milk Chocolate    103       37276
# 834              Organic Bagged Mini Dark Peanut Butter     86       45445
# 951                Organic Deep Dark Sea Salt Chocolate     76       37496
# 1100                  Organic Quinoa Dark Chocolate Bar     67       20178
# 1111                             Milk Chocolate Almonds     67       39657
#
#       aisle_id            aisle  department_id department
# 211         45  candy chocolate             19     snacks
# 287         45  candy chocolate             19     snacks
# 561         45  candy chocolate             19     snacks
# 572         45  candy chocolate             19     snacks
# 617         45  candy chocolate             19     snacks
# 689         45  candy chocolate             19     snacks
# 834         45  candy chocolate             19     snacks
# 951         45  candy chocolate             19     snacks
# 1100        45  candy chocolate             19     snacks
# 1111        45  candy chocolate             19     snacks
#                                product_name  count  product_id  aisle_id  \
# 126                    Creamy Almond Butter    407       30450        88
# 135                    Creamy Peanut Butter    386       16953        88
# 163            Organic Creamy Peanut Butter    336       43713        88
# 175                    Strawberry Preserves    323       42356        88
# 255         Organic Strawberry Fruit Spread    231       37220        88
# 319                     Raspberry Preserves    195        4656        88
# 333                   Crunchy Almond Butter    188       42557        88
# 475                   Classic Almond Butter    141       31338        88
# 478          Peanut Butter Creamy With Salt    140        8239        88
# 577  Hazelnut Spread With Skim Milk & Cocoa    119        4006        88
#
#        aisle  department_id department
# 126  spreads             13     pantry
# 135  spreads             13     pantry
# 163  spreads             13     pantry
# 175  spreads             13     pantry
# 255  spreads             13     pantry
# 319  spreads             13     pantry
# 333  spreads             13     pantry
# 475  spreads             13     pantry
# 478  spreads             13     pantry
# 577  spreads             13     pantry
#                     product_name  count  product_id  aisle_id      aisle  \
# 161                    Spaghetti    337       32734       131  dry pasta
# 310                 Penne Rigate    198       12872       131  dry pasta
# 350             Spaghetti  No 12    182        5240       131  dry pasta
# 351         Organic Penne Rigate    182       28278       131  dry pasta
# 372              Spaghetti Pasta    175       46522       131  dry pasta
# 382  Organic Whole Wheat Fusilli    171       37825       131  dry pasta
# 413                  Penne Pasta    159       14168       131  dry pasta
# 424               Fusilli No. 34    156       23801       131  dry pasta
# 498      Organic Spaghetti Pasta    134       29898       131  dry pasta
# 523       Penne Rigate #41 Pasta    129        9366       131  dry pasta
#
#      department_id       department
# 161              9  dry goods pasta
# 310              9  dry goods pasta
# 350              9  dry goods pasta
# 351              9  dry goods pasta
# 372              9  dry goods pasta
# 382              9  dry goods pasta
# 413              9  dry goods pasta
# 424              9  dry goods pasta
# 498              9  dry goods pasta
# 523              9  dry goods pasta
#                                   product_name  count  product_id  aisle_id  \
# 178  Organic Whole Grain Wheat English Muffins    318       17706        93
# 180  Original Nooks & Crannies English Muffins    313       10673        93
# 273                               Plain Bagels    222       20738        93
# 357                          Plain Mini Bagels    180       42460        93
# 396                          Everything Bagels    165       16262        93
# 397                    Plain Pre-Sliced Bagels    165       46842        93
# 404                Presliced Everything Bagels    162       17341        93
# 456                   Authentic French Brioche    148       48857        93
# 476            Organic Sprouted English Muffin    141        3849        93
#
#                 aisle  department_id department
# 178  breakfast bakery              3     bakery
# 180  breakfast bakery              3     bakery
# 273  breakfast bakery              3     bakery
# 357  breakfast bakery              3     bakery
# 396  breakfast bakery              3     bakery
# 397  breakfast bakery              3     bakery
# 404  breakfast bakery              3     bakery
# 456  breakfast bakery              3     bakery
# 476  breakfast bakery              3     bakery
#                       product_name  count  product_id  aisle_id aisle  \
# 551   Premium Unsweetened Iced Tea    123       44292        94   tea
# 668       Pink Lady Apple Kombucha    106        4462        94   tea
# 692                        Zen Tea    102       10312        94   tea
# 921        Moroccan Mint Green Tea     79       18606        94   tea
# 1054    Just Green Unsweetened Tea     70       45223        94   tea
# 1091  Unsweetened Premium Iced Tea     67       48988        94   tea
# 1096                    Ginger Tea     67       35749        94   tea
# 1225                 Earl Grey Tea     61       48946        94   tea
# 1269     Calm Chamomile Herbal Tea     59       40411        94   tea
#
#       department_id department
# 551               7  beverages
# 668               7  beverages
# 692               7  beverages
# 921               7  beverages
# 1054              7  beverages
# 1091              7  beverages
# 1096              7  beverages
# 1225              7  beverages
# 1269              7  beverages
#                                    product_name  count  product_id  aisle_id  \
# 50                       Extra Virgin Olive Oil    986       31506        19
# 227              Italian Extra Virgin Olive Oil    255       10644        19
# 320              Organic Extra Virgin Olive Oil    194       21195        19
# 346                                  Canola Oil    184       48697        19
# 353                Unrefined Virgin Coconut Oil    181       40377        19
# 363             Organic Distilled White Vinegar    179       12409        19
# 384  Organic Raw Unfiltered Apple Cider Vinegar    170        4461        19
# 419                         Apple Cider Vinegar    157       18963        19
#
#              aisle  department_id department
# 50   oils vinegars             13     pantry
# 227  oils vinegars             13     pantry
# 320  oils vinegars             13     pantry
# 346  oils vinegars             13     pantry
# 353  oils vinegars             13     pantry
# 363  oils vinegars             13     pantry
# 384  oils vinegars             13     pantry
# 419  oils vinegars             13     pantry
#                                    product_name  count  product_id  aisle_id  \
# 294                      Chocolate Chip Cookies    207       40199        61
# 302          Gluten Free Chocolate Chip Cookies    204       40063        61
# 583            Fig Newmans Fruit Filled Cookies    118       45866        61
# 609             Oreo Chocolate Sandwich Cookies    115       12481        61
# 779                         Honey Graham Sticks     91        9438        61
# 887   Newman O's Creme Filled Chocolate Cookies     81       45374        61
# 999              Cookies, Chocolate Chip Walnut     73       26634        61
# 1098                         Fudge Mint Cookies     67       42139        61
#
#               aisle  department_id department
# 294   cookies cakes             19     snacks
# 302   cookies cakes             19     snacks
# 583   cookies cakes             19     snacks
# 609   cookies cakes             19     snacks
# 779   cookies cakes             19     snacks
# 887   cookies cakes             19     snacks
# 999   cookies cakes             19     snacks
# 1098  cookies cakes             19     snacks
#                          product_name  count  product_id  aisle_id  \
# 117                    Marinara Sauce    427       23375         9
# 159                       Basil Pesto    340       12206         9
# 162  Organic Tomato Basil Pasta Sauce    336       39619         9
# 216                      Tomato Paste    269       14197         9
# 265              Marinara Pasta Sauce    225       38273         9
# 362        All Natural Marinara Sauce    179       14852         9
# 522           Four Cheese Pasta Sauce    130       31927         9
# 627      Organic Marinara Pasta Sauce    111       19478         9
#
#            aisle  department_id       department
# 117  pasta sauce              9  dry goods pasta
# 159  pasta sauce              9  dry goods pasta
# 162  pasta sauce              9  dry goods pasta
# 216  pasta sauce              9  dry goods pasta
# 265  pasta sauce              9  dry goods pasta
# 362  pasta sauce              9  dry goods pasta
# 522  pasta sauce              9  dry goods pasta
# 627  pasta sauce              9  dry goods pasta
# ...
# 941  energy sports drinks              7  beverages
#                                           product_name  count  product_id  \
# 140                                 Organic AppleApple    374       26790
# 515                                        Apple Sauce    130       45013
# 525  Gogo Squeez Organic Apple Strawberry Applesauc...    129        9598
#
#      aisle_id                    aisle  department_id    department
# 140        99  canned fruit applesauce             15  canned goods
# 515        99  canned fruit applesauce             15  canned goods
# 525        99  canned fruit applesauce             15  canned goods
#                                    product_name  count  product_id  aisle_id  \
# 325            Natural Free & Clear Dish Liquid    191       13838        74
# 474                     Lemon Verbena Dish Soap    141       33290        74
# 940  Lavender Floral & Mint Natural Dish Liquid     78        2581        74
#
#                aisle  department_id department
# 325  dish detergents             17  household
# 474  dish detergents             17  household
# 940  dish detergents             17  household
#                                            product_name  count  product_id  \
# 638   Free & Clear Natural Laundry Detergent For Sen...    109         204
# 1105  Natural Liquid Laundry Detergent - Blue Eucaly...     67         605
# 1660         Natural Laundry Detergent, Free & Clear 33     45       37357
#
#       aisle_id    aisle  department_id department
# 638         75  laundry             17  household
# 1105        75  laundry             17  household
# 1660        75  laundry             17  household
#                    product_name  count  product_id  aisle_id    aisle  \
# 388   Organic Riced Cauliflower    169       41149       100  missing
# 1466       Organic Celery Bunch     51       38510       100  missing
# 1564       Organic Mango Yogurt     48       14010       100  missing
#
#       department_id department
# 388              21    missing
# 1466             21    missing
# 1564             21    missing
#                                    product_name  count  product_id  aisle_id  \
# 306                              Taco Seasoning    201        2450        30
# 690   New Mexico Taco Skillet Sauce For Chicken    102       39430        30
# 1038               Organic Spicy Taco Seasoning     71       35167        30
#
#              aisle  department_id     department
# 306   latino foods              6  international
# 690   latino foods              6  international
# 1038  latino foods              6  international
#                                            product_name  count  product_id  \
# 1262          Frosted berry Strawberry Toaster Pastries     59       13605
# 1359  Nutri-Grain Soft Baked Strawberry Cereal Break...     55       21351
#
#       aisle_id                    aisle  department_id department
# 1262        48  breakfast bars pastries             14  breakfast
# 1359        48  breakfast bars pastries             14  breakfast
#                            product_name  count  product_id  aisle_id  \
# 703    Wild Albacore Tuna No Salt Added    101          79        95
# 751  Solid White Albacore Tuna In Water     94        4317        95
#
#                    aisle  department_id    department
# 703  canned meat seafood             15  canned goods
# 751  canned meat seafood             15  canned goods
#                             product_name  count  product_id  aisle_id  \
# 373  Organic Mountain Forest Amber Honey    174       22504        29
# 736           Organic Light Agave Nectar     96       18471        29
#
#                      aisle  department_id department
# 373  honeys syrups nectars             13     pantry
# 736  honeys syrups nectars             13     pantry
#             product_name  count  product_id  aisle_id         aisle  \
# 268        Aluminum Foil    224       31066        85  food storage
# 485  Gallon Freezer Bags    138       44643        85  food storage
#
#      department_id department
# 268             17  household
# 485             17  household
#                              product_name  count  product_id  aisle_id  \
# 2304            Instant Action Cat Litter     32       49355        41
# 2360  Grain Free Chicken Formula Cat Food     31        7076        41
#
#               aisle  department_id department
# 2304  cat food care              8       pets
# 2360  cat food care              8       pets
#                                            product_name  count  product_id  \
# 917   Fluoride-Free Antiplaque & Whitening Peppermin...     79       29418
# 1794  Natural Anticavity Silly Strawberry Fluoride T...     42        3007
#
#       aisle_id         aisle  department_id     department
# 917         20  oral hygiene             11  personal care
# 1794        20  oral hygiene             11  personal care
#                 product_name  count  product_id  aisle_id aisle  \
# 675       Lavender Hand Soap    105       12312        25  soap
# 744  Lemon Verbena Hand Soap     95       27544        25  soap
#
#      department_id     department
# 675             11  personal care
# 744             11  personal care
#                  product_name  count  product_id  aisle_id  \
# 400        Panko Bread Crumbs    164       43129         5
# 1297  Original Barbecue Sauce     58       49481         5
#
#                            aisle  department_id department
# 400   marinades meat preparation             13     pantry
# 1297  marinades meat preparation             13     pantry
#                  product_name  count  product_id  aisle_id  \
# 1147  Organic Ground Flaxseed     65        2309        47
#
#                      aisle  department_id     department
# 1147  vitamins supplements             11  personal care
#        product_name  count  product_id  aisle_id                       aisle  \
# 1076  9 Inch Plates     68       31801       111  plates bowls cups flatware
#
#       department_id department
# 1076             17  household
#                      product_name  count  product_id  aisle_id  \
# 1418  Vanilla Whey Protein Powder     52       14650        65
#
#                           aisle  department_id     department
# 1418  protein meal replacements             11  personal care
#                  product_name  count  product_id  aisle_id              aisle  \
# 2386  Deep Moisture Body Wash     31       33439       127  body lotions soap
#
#       department_id     department
# 2386             11  personal care
#                                            product_name  count  product_id  \
# 1181  Freshly Made. Filled with Creamy Ricotta, Aged...     63       39719
#
#       aisle_id        aisle  department_id       department
# 1181        12  fresh pasta              9  dry goods pasta
#                                          product_name  count  product_id  \
# 3290  Organix Grain Free Chicken & Vegetable Dog Food     21       19571
#
#       aisle_id          aisle  department_id department
# 3290        40  dog food care              8       pets
#     product_name  count  product_id  aisle_id          aisle  department_id  \
# 878         Beer     82       46088        27  beers coolers              5
#
#     department
# 878    alcohol
#               product_name  count  product_id  aisle_id  aisle  department_id  \
# 894  Roasted Almond Butter     81       38662         6  other              2
#
#     department
# 894      other
#                                            product_name  count  product_id  \
# 3134  Moroccan Argan Oil + Argan Stem Cell Triple Mo...     22       19513
#
#       aisle_id      aisle  department_id     department
# 3134        22  hair care             11  personal care
#                      product_name  count  product_id  aisle_id  \
# 797  Tall Kitchen Drawstring Bags     90       49113        60
#
#                  aisle  department_id department
# 797  trash bags liners             17  household
#     product_name  count  product_id  aisle_id                aisle  \
# 447    Trail Mix    150       37710       125  trail mix snack mix
#
#      department_id department
# 447             19     snacks
#                                 product_name  count  product_id  aisle_id  \
# 1437  Muffins, Mini, Flax, Chocolate Brownie     52        2298         8
#
#                 aisle  department_id department
# 1437  bakery desserts              3     bakery
#            product_name  count  product_id  aisle_id      aisle  \
# 674  Cabernet Sauvignon    105       33065        28  red wines
#
#      department_id department
# 674              5    alcohol
#                     product_name  count  product_id  aisle_id      aisle  \
# 2149  Organic Lowfat Mango Kefir     35       14711        70  digestion
#
#       department_id     department
# 2149             11  personal care
#         product_name  count  product_id  aisle_id        aisle  department_id  \
# 590  Sauvignon Blanc    117        2120        62  white wines              5
#
#     department
# 590    alcohol
#                          product_name  count  product_id  aisle_id  \
# 1482  Honest Face, Hand, & Baby Wipes     51        5922        56
#
#               aisle  department_id department
# 1482  diapers wipes             18     babies
#                                            product_name  count  product_id  \
# 3209  The Original Natural Herb Drops Cough Suppressant     22       36696
#
#       aisle_id             aisle  department_id     department
# 3209        11  cold flu allergy             11  personal care
#     product_name  count  product_id  aisle_id    aisle  department_id  \
# 774        Vodka     92       45190       124  spirits              5
#
#     department
# 774    alcohol
#                      product_name  count  product_id  aisle_id  \
# 1264  100% Recycled Aluminum Foil     59         160        97
#
#                       aisle  department_id department
# 1264  baking supplies decor             13     pantry
#                   product_name  count  product_id  aisle_id     aisle  \
# 3038  Spearmint Sugar-Free Gum     23       34355        46  mint gum
#
#       department_id department
# 3038             19     snacks
#                product_name  count  product_id  aisle_id          aisle  \
# 4587  Flushable Moist Wipes     14       29978       126  feminine care
#
#       department_id     department
# 4587             11  personal care
#       product_name  count  product_id  aisle_id              aisle  \
# 2921  Cocoa Powder     24       17956        90  cocoa drink mixes
#
#       department_id department
# 2921              7  beverages
#     product_name  count  product_id  aisle_id                         aisle  \
# 312  Dried Mango    198        5161        18  bulk dried fruits vegetables
#
#      department_id department
# 312             10       bulk
#                             product_name  count  product_id  aisle_id  \
# 5874  Lavender Harvest Aromatherapy Mist     10       20324       101
#
#                        aisle  department_id department
# 5874  air fresheners candles             17  household
#             product_name  count  product_id  aisle_id  \
# 494  Organic Rolled Oats    136       22260        68
#
#                             aisle  department_id department
# 494  bulk grains rice dried goods             10       bulk
#            product_name  count  product_id  aisle_id  \
# 859  Premium Epsom Salt     84        9047       133
#
#                           aisle  department_id     department
# 859  muscles joints pain relief             11  personal care
#      product_name  count  product_id  aisle_id           aisle  department_id  \
# 1102   Snack Bags     67         274        87  more household             17
#
#      department
# 1102  household
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
#                                    product_name  count  product_id  aisle_id  \
# 6029  Venus Embrace Women's Razor Blade Refills      9       38194        55
#
#             aisle  department_id     department
# 6029  shave needs             11  personal care
#            product_name  count  product_id  aisle_id      aisle  \
# 3613  Hydrogen Peroxide     19       39858       118  first aid
#
#       department_id     department
# 3613             11  personal care
#                        product_name  count  product_id  aisle_id  \
# 3247  Primordial Himalayan Sea Salt     22        7299        10
#
#                  aisle  department_id department
# 3247  kitchen supplies             17  household
#                  product_name  count  product_id  aisle_id  \
# 2604  Prosecco Sparkling Wine     28       37923       134
#
#                            aisle  department_id department
# 2604  specialty wines champagnes              5    alcohol
#                           product_name  count  product_id  aisle_id  \
# 507  Free & Clear Unscented Baby Wipes    132       44471        82
#
#                 aisle  department_id department
# 507  baby accessories             18     babies
#                      product_name  count  product_id  aisle_id  \
# 4345  Unscented Pure Castile Soap     15       31990       102
#
#                     aisle  department_id department
# 4345  baby bath body care             18     babies
#       product_name  count  product_id  aisle_id         aisle  department_id  \
# 1207  Cotton Swabs     62       33493        44  eye ear care             11
#
#          department
# 1207  personal care
#               product_name  count  product_id  aisle_id   aisle  \
# 3453  Organic Cotton Balls     20       38426       132  beauty
#
#       department_id     department
# 3453             11  personal care
#                            product_name  count  product_id  aisle_id  \
# 0                                Banana   9028       24852        24
# 1                Bag of Organic Bananas   7152       13176        24
# 2                  Organic Strawberries   5233       21137        24
# 4                  Organic Hass Avocado   4282       47209        24
# 5                       Organic Avocado   3493       47766        24
# ...                                 ...    ...         ...       ...
# 2604            Prosecco Sparkling Wine     28       37923       134
# 507   Free & Clear Unscented Baby Wipes    132       44471        82
# 4345        Unscented Pure Castile Soap     15       31990       102
# 1207                       Cotton Swabs     62       33493        44
# 3453               Organic Cotton Balls     20       38426       132
#
#                            aisle  department_id     department
# 0                   fresh fruits              4        produce
# 1                   fresh fruits              4        produce
# 2                   fresh fruits              4        produce
# 4                   fresh fruits              4        produce
# 5                   fresh fruits              4        produce
# ...                          ...            ...            ...
# 2604  specialty wines champagnes              5        alcohol
# 507             baby accessories             18         babies
# 4345         baby bath body care             18         babies
# 1207                eye ear care             11  personal care
# 3453                      beauty             11  personal care
#
# [800 rows x 7 columns]

# %%
# Sanity Check
result_df
# Out:
#                            product_name  count  product_id  aisle_id  \
# 0                                Banana   9028       24852        24
# 1                Bag of Organic Bananas   7152       13176        24
# 2                  Organic Strawberries   5233       21137        24
# 4                  Organic Hass Avocado   4282       47209        24
# 5                       Organic Avocado   3493       47766        24
# ...                                 ...    ...         ...       ...
# 2604            Prosecco Sparkling Wine     28       37923       134
# 507   Free & Clear Unscented Baby Wipes    132       44471        82
# 4345        Unscented Pure Castile Soap     15       31990       102
# 1207                       Cotton Swabs     62       33493        44
# 3453               Organic Cotton Balls     20       38426       132
#
#                            aisle  department_id     department
# 0                   fresh fruits              4        produce
# 1                   fresh fruits              4        produce
# 2                   fresh fruits              4        produce
# 4                   fresh fruits              4        produce
# 5                   fresh fruits              4        produce
# ...                          ...            ...            ...
# 2604  specialty wines champagnes              5        alcohol
# 507             baby accessories             18         babies
# 4345         baby bath body care             18         babies
# 1207                eye ear care             11  personal care
# 3453                      beauty             11  personal care
#
# [800 rows x 7 columns]

# %% [markdown]
# Next, selecting the top 100 frozen products to place in the freezer

# %%
train_freezer
# Out:
#         order_id  product_id                                  product_name  \
# 68             7       46802                              Pineapple Chunks
# 135           14         162                Organic Mini Homestyle Waffles
# 136           14        2452                      Naturals Chicken Nuggets
# 140           14       10096                         Corn Meal Pizza Crust
# 142           14       20995                      Organic Broccoli Florets
# ...          ...         ...                                           ...
# 987130     99986       42450                             Macaroni & Cheese
# 987143     99987       40203                           Mint Chip Ice Cream
# 987176     99993       43749                Organic Ice Cream Vanilla Bean
# 987180     99993        5537  Dairy Free Coconut Milk Frozen Dessert Minis
# 987184     99993       26128                          Organic Mango Chunks
#
#         aisle_id                    aisle  department_id department
# 68           116           frozen produce              1     frozen
# 135           52         frozen breakfast              1     frozen
# 136          129  frozen appetizers sides              1     frozen
# 140           58     frozen breads doughs              1     frozen
# 142          116           frozen produce              1     frozen
# ...          ...                      ...            ...        ...
# 987130        38             frozen meals              1     frozen
# 987143        37            ice cream ice              1     frozen
# 987176        37            ice cream ice              1     frozen
# 987180        37            ice cream ice              1     frozen
# 987184       116           frozen produce              1     frozen
#
# [45088 rows x 7 columns]

# %%
train_freezer['aisle'].value_counts()
# Out:
# frozen produce             10792
# ice cream ice               9497
# frozen meals                7957
# frozen breakfast            4904
# frozen appetizers sides     3985
# frozen pizza                3200
# frozen vegan vegetarian     2078
# frozen meat seafood         1347
# frozen breads doughs         848
# frozen dessert               396
# frozen juice                  84
# Name: aisle, dtype: int64

# %%
# finding the amount of items ordered for each aisle
aisle_info2 = train_freezer.groupby('aisle').size().reset_index(name='count').sort_values(by='count', ascending=False)
aisle_info2
# Out:
#                       aisle  count
# 8            frozen produce  10792
# 10            ice cream ice   9497
# 5              frozen meals   7957
# 2          frozen breakfast   4904
# 0   frozen appetizers sides   3985
# 7              frozen pizza   3200
# 9   frozen vegan vegetarian   2078
# 6       frozen meat seafood   1347
# 1      frozen breads doughs    848
# 3            frozen dessert    396
# 4              frozen juice     84

# %%
aisle_info2['percentage']=(aisle_info2['count']/train_freezer.shape[0])*100
aisle_info2
# Out:
#                       aisle  count  percentage
# 8            frozen produce  10792   23.935415
# 10            ice cream ice   9497   21.063254
# 5              frozen meals   7957   17.647711
# 2          frozen breakfast   4904   10.876508
# 0   frozen appetizers sides   3985    8.838272
# 7              frozen pizza   3200    7.097232
# 9   frozen vegan vegetarian   2078    4.608765
# 6       frozen meat seafood   1347    2.987491
# 1      frozen breads doughs    848    1.880767
# 3            frozen dessert    396    0.878282
# 4              frozen juice     84    0.186302

# %%
# calculating amount allocation for each aisle
aisle_info2['amount'] = round(aisle_info2['percentage']/100*100)
aisle_info2
# Out:
#                       aisle  count  percentage  amount
# 8            frozen produce  10792   23.935415    24.0
# 10            ice cream ice   9497   21.063254    21.0
# 5              frozen meals   7957   17.647711    18.0
# 2          frozen breakfast   4904   10.876508    11.0
# 0   frozen appetizers sides   3985    8.838272     9.0
# 7              frozen pizza   3200    7.097232     7.0
# 9   frozen vegan vegetarian   2078    4.608765     5.0
# 6       frozen meat seafood   1347    2.987491     3.0
# 1      frozen breads doughs    848    1.880767     2.0
# 3            frozen dessert    396    0.878282     1.0
# 4              frozen juice     84    0.186302     0.0

# %%
# Checking if the amount allocated is equal to 100 and not 101 or 99 due to rounding error
aisle_info2['amount'].sum()
# Out:
# 101.0

# %%
freezer_products=train_freezer.groupby('product_name').size().reset_index(name='count').sort_values(by='count', ascending=False)
freezer_products
# Out:
#                                            product_name  count
# 191                                         Blueberries   1148
# 1727                           Organic Broccoli Florets    704
# 1879                         Organic Whole Strawberries    698
# 1013                    Frozen Organic Wild Blueberries    652
# 2017                                   Pineapple Chunks    477
# ...                                                 ...    ...
# 849              Egg, Bacon & Cheese Breakfast Taquitos      1
# 848                 Egg With Sausage And Cheese Burrito      1
# 2219                            Sausage Pepperoni Pizza      1
# 2223                                  Sausage Scrambles      1
# 2860  with Sweet & Smoky BBQ Sauce Cheeseburger Sliders      1
#
# [2861 rows x 2 columns]

# %%
product_mapping = train_freezer[['product_id', 'product_name', 'aisle_id', 'aisle', 'department_id', 'department']]
product_mapping = product_mapping.drop_duplicates(subset='product_name')
freezer_products = freezer_products.merge(product_mapping, on='product_name', how='left')
freezer_products
# Out:
#                                            product_name  count  product_id  \
# 0                                           Blueberries   1148        9076
# 1                              Organic Broccoli Florets    704       20995
# 2                            Organic Whole Strawberries    698       24489
# 3                       Frozen Organic Wild Blueberries    652       17948
# 4                                      Pineapple Chunks    477       46802
# ...                                                 ...    ...         ...
# 2856             Egg, Bacon & Cheese Breakfast Taquitos      1        9676
# 2857                Egg With Sausage And Cheese Burrito      1       26213
# 2858                            Sausage Pepperoni Pizza      1        8973
# 2859                                  Sausage Scrambles      1       17058
# 2860  with Sweet & Smoky BBQ Sauce Cheeseburger Sliders      1       22156
#
#       aisle_id                    aisle  department_id department
# 0          116           frozen produce              1     frozen
# 1          116           frozen produce              1     frozen
# 2          116           frozen produce              1     frozen
# 3          116           frozen produce              1     frozen
# 4          116           frozen produce              1     frozen
# ...        ...                      ...            ...        ...
# 2856        34      frozen meat seafood              1     frozen
# 2857        38             frozen meals              1     frozen
# 2858        79             frozen pizza              1     frozen
# 2859        52         frozen breakfast              1     frozen
# 2860       129  frozen appetizers sides              1     frozen
#
# [2861 rows x 7 columns]

# %%
# Selecting the 100 frozen items for the freezer
result_df2 = pd.DataFrame()
for index, row in aisle_info2.iterrows():
    aisle_name = row['aisle']
    amount = int(row['amount'])
    display(freezer_products[freezer_products['aisle']==aisle_name].head(amount))
    result_df2 = pd.concat([result_df2, freezer_products[freezer_products['aisle']==aisle_name].head(amount)])
result_df2
# Out:
#                        product_name  count  product_id  aisle_id  \
# 0                       Blueberries   1148        9076       116
# 1          Organic Broccoli Florets    704       20995       116
# 2        Organic Whole Strawberries    698       24489       116
# 3   Frozen Organic Wild Blueberries    652       17948       116
# 4                  Pineapple Chunks    477       46802       116
# 5               Organic Frozen Peas    390       14678       116
# 7                      Mango Chunks    371        1158       116
# 9           Frozen Broccoli Florets    311       28934       116
# 10                     Berry Medley    306       40545       116
# 14          Organic Chopped Spinach    266       18918       116
# 17                       Green Peas    232       32433       116
# 20      Organic Frozen Mango Chunks    223        2228       116
# 21           Organic Sliced Peaches    219       34584       116
# 22         Organic Mixed Vegetables    216       35887       116
# 29               Whole Strawberries    178       28553       116
# 34                  Chopped Spinach    168       23236       116
# 36                   Sweet Potatoes    165       34466       116
# 39      Organic Dark Sweet Cherries    151       24082       116
# 41          Organic Cut Green Beans    150       28123       116
# 42                  Organic Edamame    149       31869       116
# 49             Organic Mango Chunks    131       26128       116
# 67              Organic Berry Blend    114       47492       116
# 75                   Frozen Peaches    107        9390       116
# 83          Petite Brussels Sprouts     97         436       116
#
#              aisle  department_id department
# 0   frozen produce              1     frozen
# 1   frozen produce              1     frozen
# 2   frozen produce              1     frozen
# 3   frozen produce              1     frozen
# 4   frozen produce              1     frozen
# 5   frozen produce              1     frozen
# 7   frozen produce              1     frozen
# 9   frozen produce              1     frozen
# 10  frozen produce              1     frozen
# 14  frozen produce              1     frozen
# 17  frozen produce              1     frozen
# 20  frozen produce              1     frozen
# 21  frozen produce              1     frozen
# 22  frozen produce              1     frozen
# 29  frozen produce              1     frozen
# 34  frozen produce              1     frozen
# 36  frozen produce              1     frozen
# 39  frozen produce              1     frozen
# 41  frozen produce              1     frozen
# 42  frozen produce              1     frozen
# 49  frozen produce              1     frozen
# 67  frozen produce              1     frozen
# 75  frozen produce              1     frozen
# 83  frozen produce              1     frozen
#                                      product_name  count  product_id  \
# 15                            Chocolate Ice Cream    241       16965
# 19                              Vanilla Ice Cream    224       32691
# 32          Chocolate Chip Cookie Dough Ice Cream    171       12276
# 44                   Ice Cream Sandwiches Vanilla    141       38274
# 50                        Sea Salt Caramel Gelato    130       41319
# 55                           Strawberry Ice Cream    123       40002
# 58                 Organic Vanilla Bean Ice Cream    120       23554
# 59                      Mediterranean Mint Gelato    120       20754
# 64                     Americone Dream® Ice Cream    116       45681
# 70                          Half Baked® Ice Cream    109       46175
# 74                   Caramel Cookie Crunch Gelato    107       13885
# 77                                      Mint Chip    104        2361
# 79                   Vanilla Bean Light Ice Cream    101       21463
# 81                   Tahitian Vanilla Bean Gelato     98       24231
# 86                   Watermelon Agave Frozen Pops     93       10199
# 91                  Birthday Cake Light Ice Cream     90       48523
# 92   Vanilla Milk Chocolate Almond Ice Cream Bars     89        8638
# 93                      Natural Vanilla Ice Cream     87       45061
# 96       Coconut Almond Minis Frozen Dessert Bars     85       47652
# 102                       Cherry Garcia Ice Cream     81       47993
# 104                              Coffee Ice Cream     80       17334
#
#      aisle_id          aisle  department_id department
# 15         37  ice cream ice              1     frozen
# 19         37  ice cream ice              1     frozen
# 32         37  ice cream ice              1     frozen
# 44         37  ice cream ice              1     frozen
# 50         37  ice cream ice              1     frozen
# 55         37  ice cream ice              1     frozen
# 58         37  ice cream ice              1     frozen
# 59         37  ice cream ice              1     frozen
# 64         37  ice cream ice              1     frozen
# 70         37  ice cream ice              1     frozen
# 74         37  ice cream ice              1     frozen
# 77         37  ice cream ice              1     frozen
# 79         37  ice cream ice              1     frozen
# 81         37  ice cream ice              1     frozen
# 86         37  ice cream ice              1     frozen
# 91         37  ice cream ice              1     frozen
# 92         37  ice cream ice              1     frozen
# 93         37  ice cream ice              1     frozen
# 96         37  ice cream ice              1     frozen
# 102        37  ice cream ice              1     frozen
# 104        37  ice cream ice              1     frozen
#                                           product_name  count  product_id  \
# 8                                    Macaroni & Cheese    342       42450
# 12                                  Organic Brown Rice    296       49075
# 26                             Pesto Tortellini  Bowls    185       34217
# 37         Organic Beans & Rice Cheddar Cheese Burrito    159       47792
# 47                   Broccoli & Cheddar Bake Meal Bowl    135        9124
# 56                                Organic Jasmine Rice    122       39121
# 57                               Bean & Cheese Burrito    122       26914
# 60                                            Pad Thai    118       45613
# 65                                     Chicken Pot Pie    115       13966
# 72   Organic Gluten Free Non-Dairy Beans & Rice Bur...    107       49416
# 80                            Butternut Squash Ravioli     98       43908
# 95   Light and Lean Quinoa Black Beans with Buttern...     85       49273
# 97                               Cheese Enchilada Meal     84        3717
# 98                            Kitchen Cheese Enchilada     82       22559
# 99                              Cheddar Cheese Burrito     82       30135
# 101                       Light & Lean Spinach Lasagna     81       24631
# 111     Gluten and Dairy Free Rice Macaroni and Cheeze     76       14126
# 118                            Organic Chicken Pot Pie     72        8929
#
#      aisle_id         aisle  department_id department
# 8          38  frozen meals              1     frozen
# 12         38  frozen meals              1     frozen
# 26         38  frozen meals              1     frozen
# 37         38  frozen meals              1     frozen
# 47         38  frozen meals              1     frozen
# 56         38  frozen meals              1     frozen
# 57         38  frozen meals              1     frozen
# 60         38  frozen meals              1     frozen
# 65         38  frozen meals              1     frozen
# 72         38  frozen meals              1     frozen
# 80         38  frozen meals              1     frozen
# 95         38  frozen meals              1     frozen
# 97         38  frozen meals              1     frozen
# 98         38  frozen meals              1     frozen
# 99         38  frozen meals              1     frozen
# 101        38  frozen meals              1     frozen
# 111        38  frozen meals              1     frozen
# 118        38  frozen meals              1     frozen
#                                   product_name  count  product_id  aisle_id  \
# 6            Chicken & Maple Breakfast Sausage    378       37158        52
# 16                  Organic Multigrain Waffles    234        9825        52
# 25      Natural Classic Pork Breakfast Sausage    190        9515        52
# 27                   Organic Homestyle Waffles    181       25753        52
# 28                      Eggo Homestyle Waffles    178       30696        52
# 31    Naturals Savory Turkey Breakfast Sausage    175         311        52
# 35                   Organic Blueberry Waffles    166        2326        52
# 46               Gluten Free Blueberry Waffles    135       17807        52
# 48                   Wheat Gluten Free Waffles    134       24010        52
# 62              Organic Mini Homestyle Waffles    117         162        52
# 68  Organic All Natural Blueberry Mini Waffles    110       20327        52
#
#                aisle  department_id department
# 6   frozen breakfast              1     frozen
# 16  frozen breakfast              1     frozen
# 25  frozen breakfast              1     frozen
# 27  frozen breakfast              1     frozen
# 28  frozen breakfast              1     frozen
# 31  frozen breakfast              1     frozen
# 35  frozen breakfast              1     frozen
# 46  frozen breakfast              1     frozen
# 48  frozen breakfast              1     frozen
# 62  frozen breakfast              1     frozen
# 68  frozen breakfast              1     frozen
#                                   product_name  count  product_id  aisle_id  \
# 24                    Naturals Chicken Nuggets    199        2452       129
# 30                         Cheese Pizza Snacks    178       31766       129
# 33  Air Chilled Breaded Chicken Breast Nuggets    169       17652       129
# 38              Chicken Breast Tenders Breaded    156       11440       129
# 40      Kidz All Natural Baked Chicken Nuggets    151        1215       129
# 45                        Shredded Hash Browns    137       48171       129
# 52            Sweet Potato Fries with Sea Salt    129       46346       129
# 63                  Organic Yukon Select Fries    116       14881       129
# 76                            Shoestring Fries    106       48720       129
#
#                       aisle  department_id department
# 24  frozen appetizers sides              1     frozen
# 30  frozen appetizers sides              1     frozen
# 33  frozen appetizers sides              1     frozen
# 38  frozen appetizers sides              1     frozen
# 40  frozen appetizers sides              1     frozen
# 45  frozen appetizers sides              1     frozen
# 52  frozen appetizers sides              1     frozen
# 63  frozen appetizers sides              1     frozen
# 76  frozen appetizers sides              1     frozen
#                     product_name  count  product_id  aisle_id         aisle  \
# 13   Organic Cheese Frozen Pizza    273       24561        79  frozen pizza
# 23    Thin Crust Pepperoni Pizza    199       20345        79  frozen pizza
# 51              Margherita Pizza    130        5449        79  frozen pizza
# 53                  Cheese Pizza    129        9741        79  frozen pizza
# 54  Four Cheese Thin Crust Pizza    127        5959        79  frozen pizza
# 71                 Spinach Pizza    109        8022        79  frozen pizza
# 82                Pizza 4 Cheese     98        8012        79  frozen pizza
#
#     department_id department
# 13              1     frozen
# 23              1     frozen
# 51              1     frozen
# 53              1     frozen
# 54              1     frozen
# 71              1     frozen
# 82              1     frozen
#                            product_name  count  product_id  aisle_id  \
# 43           Seven Grain Crispy Tenders    143       38944        42
# 87     California Veggie Burgers - 4 CT     93       45364        42
# 105           Beyond Beef Beefy Crumble     80        2979        42
# 116                      Chik'n Nuggets     73       15950        42
# 130  The \"World's Best\" Veggie Burger     66        2002        42
#
#                        aisle  department_id department
# 43   frozen vegan vegetarian              1     frozen
# 87   frozen vegan vegetarian              1     frozen
# 105  frozen vegan vegetarian              1     frozen
# 116  frozen vegan vegetarian              1     frozen
# 130  frozen vegan vegetarian              1     frozen
#                                        product_name  count  product_id  \
# 18                           Organic Chicken Strips    225       43504
# 61                      Gluten-Free Chicken Nuggets    117       12144
# 66  Natural Chicken & Maple Breakfast Sausage Patty    114       48287
#
#     aisle_id                aisle  department_id department
# 18        34  frozen meat seafood              1     frozen
# 61        34  frozen meat seafood              1     frozen
# 66        34  frozen meat seafood              1     frozen
#                       product_name  count  product_id  aisle_id  \
# 11   Gluten Free Whole Grain Bread    299        7963        58
# 125                    Pizza Dough     68       18908        58
#
#                     aisle  department_id department
# 11   frozen breads doughs              1     frozen
# 125  frozen breads doughs              1     frozen
#                      product_name  count  product_id  aisle_id  \
# 85  Dark Chocolate Covered Banana     93       43889       119
#
#              aisle  department_id department
# 85  frozen dessert              1     frozen
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
#                                         product_name  count  product_id  \
# 0                                        Blueberries   1148        9076
# 1                           Organic Broccoli Florets    704       20995
# 2                         Organic Whole Strawberries    698       24489
# 3                    Frozen Organic Wild Blueberries    652       17948
# 4                                   Pineapple Chunks    477       46802
# ..                                               ...    ...         ...
# 61                       Gluten-Free Chicken Nuggets    117       12144
# 66   Natural Chicken & Maple Breakfast Sausage Patty    114       48287
# 11                     Gluten Free Whole Grain Bread    299        7963
# 125                                      Pizza Dough     68       18908
# 85                     Dark Chocolate Covered Banana     93       43889
#
#      aisle_id                 aisle  department_id department
# 0         116        frozen produce              1     frozen
# 1         116        frozen produce              1     frozen
# 2         116        frozen produce              1     frozen
# 3         116        frozen produce              1     frozen
# 4         116        frozen produce              1     frozen
# ..        ...                   ...            ...        ...
# 61         34   frozen meat seafood              1     frozen
# 66         34   frozen meat seafood              1     frozen
# 11         58  frozen breads doughs              1     frozen
# 125        58  frozen breads doughs              1     frozen
# 85        119        frozen dessert              1     frozen
#
# [101 rows x 7 columns]

# %% [markdown]
# Next, 100 items to put in the fridge.

# %%
train_fridge
# Out:
#         order_id  product_id                                   product_name  \
# 0              1       49302                               Bulgarian Yogurt
# 1              1       11109  Organic 4% Milk Fat Whole Milk Cottage Cheese
# 7              1       22035                    Organic Whole String Cheese
# 8              2       33120                             Organic Egg Whites
# 40             5       47329                              Fresh Fruit Salad
# ...          ...         ...                                            ...
# 987218     99997       19348                                  Fat Free Milk
# 987229     99997        3457   Swedish Style Non-Fat Drinkable Yogurt Plain
# 987233     99997       40962                 Mediterranee Cappuccino Yogurt
# 987253    100000       30489                                Original Hummus
# 987254    100000       30169        Total 2% All Natural Plain Greek Yogurt
#
#         aisle_id                  aisle  department_id  department
# 0            120                 yogurt             16  dairy eggs
# 1            108   other creams cheeses             16  dairy eggs
# 7             21        packaged cheese             16  dairy eggs
# 8             86                   eggs             16  dairy eggs
# 40             1  prepared soups salads             20        deli
# ...          ...                    ...            ...         ...
# 987218        84                   milk             16  dairy eggs
# 987229       120                 yogurt             16  dairy eggs
# 987233       120                 yogurt             16  dairy eggs
# 987253        67   fresh dips tapenades             20        deli
# 987254       120                 yogurt             16  dairy eggs
#
# [142713 rows x 7 columns]

# %%
train_fridge['aisle'].value_counts()
# Out:
# yogurt                           29680
# packaged cheese                  20230
# milk                             16517
# soy lactosefree                  12285
# eggs                              8862
# lunch meat                        8191
# fresh dips tapenades              7129
# other creams cheeses              6330
# hot dogs bacon sausage            6214
# cream                             5874
# butter                            5001
# tofu meat alternatives            2796
# poultry counter                   2577
# packaged poultry                  2346
# prepared meals                    1794
# specialty cheeses                 1681
# prepared soups salads             1386
# meat counter                      1374
# refrigerated pudding desserts      764
# packaged meat                      664
# seafood counter                    598
# packaged seafood                   420
# Name: aisle, dtype: int64

# %%
# finding the amount of items ordered for each aisle
aisle_info3 = train_fridge.groupby('aisle').size().reset_index(name='count').sort_values(by='count', ascending=False)
aisle_info3
# Out:
#                             aisle  count
# 21                         yogurt  29680
# 9                 packaged cheese  20230
# 7                            milk  16517
# 18                soy lactosefree  12285
# 2                            eggs   8862
# 5                      lunch meat   8191
# 3            fresh dips tapenades   7129
# 8            other creams cheeses   6330
# 4          hot dogs bacon sausage   6214
# 1                           cream   5874
# 0                          butter   5001
# 20         tofu meat alternatives   2796
# 13                poultry counter   2577
# 11               packaged poultry   2346
# 14                 prepared meals   1794
# 19              specialty cheeses   1681
# 15          prepared soups salads   1386
# 6                    meat counter   1374
# 16  refrigerated pudding desserts    764
# 10                  packaged meat    664
# 17                seafood counter    598
# 12               packaged seafood    420

# %%
aisle_info3['percentage']=(aisle_info3['count']/train_fridge.shape[0])*100
aisle_info3
# Out:
#                             aisle  count  percentage
# 21                         yogurt  29680   20.796984
# 9                 packaged cheese  20230   14.175303
# 7                            milk  16517   11.573578
# 18                soy lactosefree  12285    8.608186
# 2                            eggs   8862    6.209666
# 5                      lunch meat   8191    5.739491
# 3            fresh dips tapenades   7129    4.995340
# 8            other creams cheeses   6330    4.435475
# 4          hot dogs bacon sausage   6214    4.354193
# 1                           cream   5874    4.115953
# 0                          butter   5001    3.504236
# 20         tofu meat alternatives   2796    1.959177
# 13                poultry counter   2577    1.805722
# 11               packaged poultry   2346    1.643859
# 14                 prepared meals   1794    1.257068
# 19              specialty cheeses   1681    1.177888
# 15          prepared soups salads   1386    0.971180
# 6                    meat counter   1374    0.962771
# 16  refrigerated pudding desserts    764    0.535340
# 10                  packaged meat    664    0.465269
# 17                seafood counter    598    0.419023
# 12               packaged seafood    420    0.294297

# %%
# calculating amount allocation for each aisle
aisle_info3['amount'] = round(aisle_info3['percentage']/100*100)
aisle_info3
# Out:
#                             aisle  count  percentage  amount
# 21                         yogurt  29680   20.796984    21.0
# 9                 packaged cheese  20230   14.175303    14.0
# 7                            milk  16517   11.573578    12.0
# 18                soy lactosefree  12285    8.608186     9.0
# 2                            eggs   8862    6.209666     6.0
# 5                      lunch meat   8191    5.739491     6.0
# 3            fresh dips tapenades   7129    4.995340     5.0
# 8            other creams cheeses   6330    4.435475     4.0
# 4          hot dogs bacon sausage   6214    4.354193     4.0
# 1                           cream   5874    4.115953     4.0
# 0                          butter   5001    3.504236     4.0
# 20         tofu meat alternatives   2796    1.959177     2.0
# 13                poultry counter   2577    1.805722     2.0
# 11               packaged poultry   2346    1.643859     2.0
# 14                 prepared meals   1794    1.257068     1.0
# 19              specialty cheeses   1681    1.177888     1.0
# 15          prepared soups salads   1386    0.971180     1.0
# 6                    meat counter   1374    0.962771     1.0
# 16  refrigerated pudding desserts    764    0.535340     1.0
# 10                  packaged meat    664    0.465269     0.0
# 17                seafood counter    598    0.419023     0.0
# 12               packaged seafood    420    0.294297     0.0

# %%
# Checking if the amount allocated is equal to 100 and not 101 or 99 due to rounding error
aisle_info3['amount'].sum()
# Out:
# 100.0

# %% [markdown]
# Since there is 99, 1 more item needs to be added which will be a packaged meat rounded from 0 to 1.

# %%
# finding the aisle with an amount of 1 and least amount of orders
first_row = aisle_info3[aisle_info3['amount']==0].iloc[0]
first_row[0]
# Out:
# 'packaged meat'

# %%
aisle_info3.loc[aisle_info3['aisle'] == first_row[0], 'amount'] = 1
aisle_info3['amount'].sum()
# Out:
# 101.0

# %%
fridge_products=train_fridge.groupby('product_name').size().reset_index(name='count').sort_values(by='count', ascending=False)
fridge_products
# Out:
#                            product_name  count
# 2826                 Organic Whole Milk   2572
# 2898                    Original Hummus   1468
# 2594                Organic Half & Half   1450
# 1610                        Half & Half   1306
# 2835        Organic Whole String Cheese   1271
# ...                                 ...    ...
# 1040   Dairy Pure Whole Milk +Vitamin D      1
# 3315                    Roasted Chicken      1
# 3313            Roasted Brussel Sprouts      1
# 3311  Roast Turkey Breast Slices Turkey      1
# 4344                      pumpkin spice      1
#
# [4345 rows x 2 columns]

# %%
product_mapping = train_fridge[['product_id', 'product_name', 'aisle_id', 'aisle', 'department_id', 'department']]
product_mapping = product_mapping.drop_duplicates(subset='product_name')
fridge_products = fridge_products.merge(product_mapping, on='product_name', how='left')
fridge_products
# Out:
#                            product_name  count  product_id  aisle_id  \
# 0                    Organic Whole Milk   2572       27845        84
# 1                       Original Hummus   1468       30489        67
# 2                   Organic Half & Half   1450       49235        53
# 3                           Half & Half   1306       27086        53
# 4           Organic Whole String Cheese   1271       22035        21
# ...                                 ...    ...         ...       ...
# 4340   Dairy Pure Whole Milk +Vitamin D      1       48846        84
# 4341                    Roasted Chicken      1       15586        13
# 4342            Roasted Brussel Sprouts      1       15552        13
# 4343  Roast Turkey Breast Slices Turkey      1       13773        96
# 4344                      pumpkin spice      1       12821        53
#
#                      aisle  department_id  department
# 0                     milk             16  dairy eggs
# 1     fresh dips tapenades             20        deli
# 2                    cream             16  dairy eggs
# 3                    cream             16  dairy eggs
# 4          packaged cheese             16  dairy eggs
# ...                    ...            ...         ...
# 4340                  milk             16  dairy eggs
# 4341        prepared meals             20        deli
# 4342        prepared meals             20        deli
# 4343            lunch meat             20        deli
# 4344                 cream             16  dairy eggs
#
# [4345 rows x 7 columns]

# %%
# Selecting the 100 items for the fridge
result_df3 = pd.DataFrame()
for index, row in aisle_info3.iterrows():
    aisle_name = row['aisle']
    amount = int(row['amount'])
    display(fridge_products[fridge_products['aisle']==aisle_name].head(amount))
    result_df3 = pd.concat([result_df3, fridge_products[fridge_products['aisle']==aisle_name].head(amount)])
result_df3
# Out:
#                                           product_name  count  product_id  \
# 22   Total 2% with Strawberry Lowfat Greek Strained...    653       33754
# 33                        Total 0% Nonfat Greek Yogurt    536       46676
# 34                         Total Greek Strained Yogurt    517       39475
# 38                               Total 0% Greek Yogurt    502       20842
# 41   Total 2% All Natural Greek Strained Yogurt wit...    468       18523
# 44   YoKids Squeezers Organic Low-Fat Yogurt, Straw...    447       17600
# 46   Total 2% Lowfat Greek Strained Yogurt With Blu...    440        4957
# 50    Total 2% Lowfat Greek Strained Yogurt with Peach    425       33787
# 60       Icelandic Style Skyr Blueberry Non-fat Yogurt    375       28465
# 61   Total 2% Greek Strained Yogurt with Cherry 5.3 oz    373       40571
# 63                  Total 2% Lowfat Plain Greek Yogurt    353       17872
# 67             Total 2% All Natural Plain Greek Yogurt    343       30169
# 68   Total 2% All Natural Low Fat 2% Milkfat Greek ...    337       42244
# 71                          Vanilla Skyr Nonfat Yogurt    332       24799
# 76                            Non Fat Raspberry Yogurt    321       36865
# 82                  Total 0% Nonfat Plain Greek Yogurt    293       28156
# 84                             Whole Milk Plain Yogurt    285        6104
# 90                     Organic Plain Whole Milk Yogurt    276       42445
# 105              Organic Plain Greek Whole Milk Yogurt    256       25138
# 106                                 Plain Greek Yogurt    256       11422
# 111       YoKids Blueberry & Strawberry/Vanilla Yogurt    250       46584
#
#      aisle_id   aisle  department_id  department
# 22        120  yogurt             16  dairy eggs
# 33        120  yogurt             16  dairy eggs
# 34        120  yogurt             16  dairy eggs
# 38        120  yogurt             16  dairy eggs
# 41        120  yogurt             16  dairy eggs
# 44        120  yogurt             16  dairy eggs
# 46        120  yogurt             16  dairy eggs
# 50        120  yogurt             16  dairy eggs
# 60        120  yogurt             16  dairy eggs
# 61        120  yogurt             16  dairy eggs
# 63        120  yogurt             16  dairy eggs
# 67        120  yogurt             16  dairy eggs
# 68        120  yogurt             16  dairy eggs
# 71        120  yogurt             16  dairy eggs
# 76        120  yogurt             16  dairy eggs
# 82        120  yogurt             16  dairy eggs
# 84        120  yogurt             16  dairy eggs
# 90        120  yogurt             16  dairy eggs
# 105       120  yogurt             16  dairy eggs
# 106       120  yogurt             16  dairy eggs
# 111       120  yogurt             16  dairy eggs
#                                           product_name  count  product_id  \
# 4                          Organic Whole String Cheese   1271       22035
# 7                                      Grated Parmesan    962       33731
# 12                                   Shredded Parmesan    775        4799
# 15                                Feta Cheese Crumbles    690       40604
# 17   Organic Sticks Low Moisture Part Skim Mozzarel...    682        7781
# 27                        Shredded Mild Cheddar Cheese    575       31343
# 28                                Sharp Cheddar Cheese    570       16185
# 48                                 Shredded Mozzarella    439       29987
# 53        Organic Mexican Blend Finely Shredded Cheese    407       41665
# 55                         Organic Shredded Mozzarella    386       18370
# 56                     Organic American Cheese Singles    383       10132
# 74                        Mini Original Babybel Cheese    325        6348
# 107                               Goat Cheese Crumbles    256       33401
# 114                                Colby Cheese Sticks    243       44765
#
#      aisle_id            aisle  department_id  department
# 4          21  packaged cheese             16  dairy eggs
# 7          21  packaged cheese             16  dairy eggs
# 12         21  packaged cheese             16  dairy eggs
# 15         21  packaged cheese             16  dairy eggs
# 17         21  packaged cheese             16  dairy eggs
# 27         21  packaged cheese             16  dairy eggs
# 28         21  packaged cheese             16  dairy eggs
# 48         21  packaged cheese             16  dairy eggs
# 53         21  packaged cheese             16  dairy eggs
# 55         21  packaged cheese             16  dairy eggs
# 56         21  packaged cheese             16  dairy eggs
# 74         21  packaged cheese             16  dairy eggs
# 107        21  packaged cheese             16  dairy eggs
# 114        21  packaged cheese             16  dairy eggs
#                     product_name  count  product_id  aisle_id aisle  \
# 0             Organic Whole Milk   2572       27845        84  milk
# 9    Organic Reduced Fat 2% Milk    903        5785        84  milk
# 18           2% Reduced Fat Milk    682       23909        84  milk
# 23                    Whole Milk    639        4210        84  milk
# 24      Organic Reduced Fat Milk    637       38689        84  milk
# 35                 Fat Free Milk    507       19348        84  milk
# 37                  Organic Milk    505        1463        84  milk
# 39         Organic Fat Free Milk    501       36011        84  milk
# 51   Organic 2% Reduced Fat Milk    410        1940        84  milk
# 57      Milk, Organic, Vitamin D    382       29447        84  milk
# 81   2% Reduced Fat Organic Milk    295       40174        84  milk
# 85  Organic Whole Grassmilk Milk    279         329        84  milk
#
#     department_id  department
# 0              16  dairy eggs
# 9              16  dairy eggs
# 18             16  dairy eggs
# 23             16  dairy eggs
# 24             16  dairy eggs
# 35             16  dairy eggs
# 37             16  dairy eggs
# 39             16  dairy eggs
# 51             16  dairy eggs
# 57             16  dairy eggs
# 81             16  dairy eggs
# 85             16  dairy eggs
#                                        product_name  count  product_id  \
# 5                   Organic Unsweetened Almond Milk   1048       35951
# 8                            Unsweetened Almondmilk    953       24838
# 16   Unsweetened Original Almond Breeze Almond Milk    688       47144
# 30                Vanilla Almond Breeze Almond Milk    552         432
# 31                             Organic Coconut Milk    546       25659
# 36                  Unsweetened Vanilla Almond Milk    506       43295
# 72          Organic Unsweetened Vanilla Almond Milk    331       14084
# 97                 Original Pure Creamy Almond Milk    266       19677
# 104        Organic Whipped Naturally Buttery Spread    256        7175
#
#      aisle_id            aisle  department_id  department
# 5          91  soy lactosefree             16  dairy eggs
# 8          91  soy lactosefree             16  dairy eggs
# 16         91  soy lactosefree             16  dairy eggs
# 30         91  soy lactosefree             16  dairy eggs
# 31         91  soy lactosefree             16  dairy eggs
# 36         91  soy lactosefree             16  dairy eggs
# 72         91  soy lactosefree             16  dairy eggs
# 97         91  soy lactosefree             16  dairy eggs
# 104        91  soy lactosefree             16  dairy eggs
#                                    product_name  count  product_id  aisle_id  \
# 11  Organic Grade A Free Range Large Brown Eggs    813       18465        86
# 13                          Large Alfresco Eggs    773       11520        86
# 19  Organic Large Brown Grade AA Cage Free Eggs    676       30233        86
# 40            Organic Large Grade AA Brown Eggs    498       32655        86
# 59                           Organic Egg Whites    379       33120        86
# 73             Organic Grade A Large Brown Eggs    330       46654        86
#
#    aisle  department_id  department
# 11  eggs             16  dairy eggs
# 13  eggs             16  dairy eggs
# 19  eggs             16  dairy eggs
# 40  eggs             16  dairy eggs
# 59  eggs             16  dairy eggs
# 73  eggs             16  dairy eggs
#                              product_name  count  product_id  aisle_id  \
# 10                   Uncured Genoa Salami    887       27344        96
# 26          Organic Roasted Turkey Breast    607       22963        96
# 52             Oven Roasted Turkey Breast    410       40310        96
# 65                  Roasted Turkey Breast    347       42342        96
# 89                Uncured Slow Cooked Ham    276       19019        96
# 99  Organic Roasted Sliced Chicken Breast    264       36735        96
#
#          aisle  department_id department
# 10  lunch meat             20       deli
# 26  lunch meat             20       deli
# 52  lunch meat             20       deli
# 65  lunch meat             20       deli
# 89  lunch meat             20       deli
# 99  lunch meat             20       deli
#                  product_name  count  product_id  aisle_id  \
# 1             Original Hummus   1468       30489        67
# 66  Roasted Red Pepper Hummus    344       21019        67
# 69                  Guacamole    333       40396        67
# 75               Lemon Hummus    324       13646        67
# 83    Organic Original Hommus    287        2825        67
#
#                    aisle  department_id department
# 1   fresh dips tapenades             20       deli
# 66  fresh dips tapenades             20       deli
# 69  fresh dips tapenades             20       deli
# 75  fresh dips tapenades             20       deli
# 83  fresh dips tapenades             20       deli
#              product_name  count  product_id  aisle_id                 aisle  \
# 25   Whipped Cream Cheese    629       42828       108  other creams cheeses
# 29     Organic Sour Cream    569       42701       108  other creams cheeses
# 47             Sour Cream    439       23734       108  other creams cheeses
# 103   Cream Cheese Spread    258       37029       108  other creams cheeses
#
#      department_id  department
# 25              16  dairy eggs
# 29              16  dairy eggs
# 47              16  dairy eggs
# 103             16  dairy eggs
#                                 product_name  count  product_id  aisle_id  \
# 45       Uncured Hickory Smoked Sunday Bacon    444       47672       106
# 70                     Organic Beef Hot Dogs    332       45633       106
# 77  Natural Chicken & Sage Breakfast Sausage    318       27695       106
# 78                      Organic Turkey Bacon    313        5646       106
#
#                      aisle  department_id    department
# 45  hot dogs bacon sausage             12  meat seafood
# 70  hot dogs bacon sausage             12  meat seafood
# 77  hot dogs bacon sausage             12  meat seafood
# 78  hot dogs bacon sausage             12  meat seafood
#                     product_name  count  product_id  aisle_id  aisle  \
# 2            Organic Half & Half   1450       49235        53  cream
# 3                    Half & Half   1306       27086        53  cream
# 43  Organic Heavy Whipping Cream    453       18531        53  cream
# 62          Heavy Whipping Cream    367       44987        53  cream
#
#     department_id  department
# 2              16  dairy eggs
# 3              16  dairy eggs
# 43             16  dairy eggs
# 62             16  dairy eggs
#                   product_name  count  product_id  aisle_id   aisle  \
# 14             Unsalted Butter    737       42736        36  butter
# 20           Pure Irish Butter    670       33000        36  butter
# 49     Organic Unsalted Butter    427        7948        36  butter
# 54  Unsalted Pure Irish Butter    392        2078        36  butter
#
#     department_id  department
# 14             16  dairy eggs
# 20             16  dairy eggs
# 49             16  dairy eggs
# 54             16  dairy eggs
#                 product_name  count  product_id  aisle_id  \
# 21   Organic Extra Firm Tofu    655       42585        14
# 127                Firm Tofu    225       41588        14
#
#                       aisle  department_id department
# 21   tofu meat alternatives             20       deli
# 127  tofu meat alternatives             20       deli
#                         product_name  count  product_id  aisle_id  \
# 32              Ground Turkey Breast    541       38293        35
# 42  Boneless Skinless Chicken Breast    455        6046        35
#
#               aisle  department_id    department
# 32  poultry counter             12  meat seafood
# 42  poultry counter             12  meat seafood
#                                  product_name  count  product_id  aisle_id  \
# 6           Boneless Skinless Chicken Breasts    965       25890        49
# 220  Boneless Skinless Chicken Breast Fillets    143       27360        49
#
#                 aisle  department_id    department
# 6    packaged poultry             12  meat seafood
# 220  packaged poultry             12  meat seafood
#                     product_name  count  product_id  aisle_id           aisle  \
# 235  Original Rotisserie Chicken    138       28373        13  prepared meals
#
#      department_id department
# 235             20       deli
#               product_name  count  product_id  aisle_id              aisle  \
# 139  Fresh Mozzarella Ball    210       37524         2  specialty cheeses
#
#      department_id  department
# 139             16  dairy eggs
#     product_name  count  product_id  aisle_id                  aisle  \
# 283   Tuna Salad    112       26047         1  prepared soups salads
#
#      department_id department
# 283             20       deli
#              product_name  count  product_id  aisle_id         aisle  \
# 116  85% Lean Ground Beef    239       13198       122  meat counter
#
#      department_id    department
# 116             12  meat seafood
#                      product_name  count  product_id  aisle_id  \
# 469  Original Recipe Rice Pudding     68       32981        71
#
#                              aisle  department_id  department
# 469  refrigerated pudding desserts             16  dairy eggs
#                product_name  count  product_id  aisle_id          aisle  \
# 168  Organic Chicken Thighs    178       34530         7  packaged meat
#
#      department_id    department
# 168             12  meat seafood
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
# Empty DataFrame
# Columns: [product_name, count, product_id, aisle_id, aisle, department_id, department]
# Index: []
#                                           product_name  count  product_id  \
# 22   Total 2% with Strawberry Lowfat Greek Strained...    653       33754
# 33                        Total 0% Nonfat Greek Yogurt    536       46676
# 34                         Total Greek Strained Yogurt    517       39475
# 38                               Total 0% Greek Yogurt    502       20842
# 41   Total 2% All Natural Greek Strained Yogurt wit...    468       18523
# ..                                                 ...    ...         ...
# 139                              Fresh Mozzarella Ball    210       37524
# 283                                         Tuna Salad    112       26047
# 116                               85% Lean Ground Beef    239       13198
# 469                       Original Recipe Rice Pudding     68       32981
# 168                             Organic Chicken Thighs    178       34530
#
#      aisle_id                          aisle  department_id    department
# 22        120                         yogurt             16    dairy eggs
# 33        120                         yogurt             16    dairy eggs
# 34        120                         yogurt             16    dairy eggs
# 38        120                         yogurt             16    dairy eggs
# 41        120                         yogurt             16    dairy eggs
# ..        ...                            ...            ...           ...
# 139         2              specialty cheeses             16    dairy eggs
# 283         1          prepared soups salads             20          deli
# 116       122                   meat counter             12  meat seafood
# 469        71  refrigerated pudding desserts             16    dairy eggs
# 168         7                  packaged meat             12  meat seafood
#
# [101 rows x 7 columns]

# %% [markdown]
# Now that there 800 items have been selected for the aisle, 100 for the freezer and 100 for the fridge, these items need to be put all in one list and combined to compare with a combined test_aisle, test_freezer, and test_fridge.

# %%
full_aisle = pd.concat([result_df, result_df2, result_df3])

# %%
full_aisle
# Out:
#                      product_name  count  product_id  aisle_id  \
# 0                          Banana   9028       24852        24
# 1          Bag of Organic Bananas   7152       13176        24
# 2            Organic Strawberries   5233       21137        24
# 4            Organic Hass Avocado   4282       47209        24
# 5                 Organic Avocado   3493       47766        24
# ..                            ...    ...         ...       ...
# 139         Fresh Mozzarella Ball    210       37524         2
# 283                    Tuna Salad    112       26047         1
# 116          85% Lean Ground Beef    239       13198       122
# 469  Original Recipe Rice Pudding     68       32981        71
# 168        Organic Chicken Thighs    178       34530         7
#
#                              aisle  department_id    department
# 0                     fresh fruits              4       produce
# 1                     fresh fruits              4       produce
# 2                     fresh fruits              4       produce
# 4                     fresh fruits              4       produce
# 5                     fresh fruits              4       produce
# ..                             ...            ...           ...
# 139              specialty cheeses             16    dairy eggs
# 283          prepared soups salads             20          deli
# 116                   meat counter             12  meat seafood
# 469  refrigerated pudding desserts             16    dairy eggs
# 168                  packaged meat             12  meat seafood
#
# [1002 rows x 7 columns]

# %%
test = pd.concat([test_aisle,test_freezer,test_fridge])
test
# Out:
#         order_id  product_id                              product_name  \
# 19             3       17704                                    Lemons
# 20             3       21903                      Organic Baby Spinach
# 22             3       46667                       Organic Ginger Root
# 24             3       32665  Organic Ezekiel 49 Bread Cinnamon Raisin
# 64             6       40462                                   Cleanse
# ...          ...         ...                                       ...
# 987213     99996       26900                  USDA AA Extra Large Eggs
# 987240     99999       36186               Large Grade AA Organic Eggs
# 987241     99999       10034       Reduced Fat Mozarella String Cheese
# 987242     99999       44085          Vanilla Light & Fit Greek Yogurt
# 987243     99999        9558      Non-Fat Vanilla Blended Greek Yogurt
#
#         aisle_id                       aisle  department_id  department
# 19           123  packaged vegetables fruits              4     produce
# 20           123  packaged vegetables fruits              4     produce
# 22            83            fresh vegetables              4     produce
# 24           112                       bread              3      bakery
# 64            31                refrigerated              7   beverages
# ...          ...                         ...            ...         ...
# 987213        86                        eggs             16  dairy eggs
# 987240        86                        eggs             16  dairy eggs
# 987241        21             packaged cheese             16  dairy eggs
# 987242       120                      yogurt             16  dairy eggs
# 987243       120                      yogurt             16  dairy eggs
#
# [340067 rows x 7 columns]

# %%
# join the test data with my pick on 'product_id'
test_my_pick = test.merge(full_aisle, on='product_id', how='left')

# group by 'order_id' and count the non-null values of 'product_name_y' column
metrics_tmp = test_my_pick[['order_id', 'product_name_y']].groupby('order_id').count().reset_index().rename(columns={'product_name_y': "num_prod_matching"})
metrics_tmp.head()
# Out:
#    order_id  num_prod_matching
# 0         3                  4
# 1         6                  0
# 2         8                  0
# 3         9                  8
# 4        11                  2

# %%
pd.concat([train_aisle, train_freezer, train_fridge])['order_id'].nunique()
# Out:
# 48599

# %%
# calculate total unique orders in the test data
tot_order = test['order_id'].nunique()
print(f"Total number of orders: {tot_order}")
# Out:
# Total number of orders: 49234

# %%
# calculate the average number of items in each order
avg_item = len(test) / tot_order
print(f"Average number of items in each order: {avg_item}")
# Out:
# Average number of items in each order: 6.907157655278873

# %%
# calculate metric 1
# count orders with at least a match
metric_1 = len(metrics_tmp[metrics_tmp['num_prod_matching']>0])
print(f"{metric_1} of them utilize the in-aisle items. That's about {metric_1/tot_order*100:.2f}%.")
# Out:
# 42126 of them utilize the in-aisle items. That's about 85.56%.

# %%
# calculate metric 2
metric_2 = metrics_tmp['num_prod_matching'].sum() / len(metrics_tmp)
print(f"On average there are {avg_item:.2f} items in each order, and {metric_2:.2f} of them utilize in-aisle items. That's about {metric_2/avg_item*100:.2f}%")
# Out:
# On average there are 6.91 items in each order, and 3.46 of them utilize in-aisle items. That's about 50.07%

# %%
df['aisle'].value_counts()
# Out:
# fresh fruits                  110888
# fresh vegetables              103891
# packaged vegetables fruits     54207
# yogurt                         43857
# packaged cheese                29770
#                                ...
# kitchen supplies                 274
# baby accessories                 242
# baby bath body care              232
# beauty                           154
# frozen juice                     135
# Name: aisle, Length: 134, dtype: int64

# %%
department_count = df['department'].value_counts()

# %%
department_count
# Out:
# produce            288775
# dairy eggs         164468
# snacks              88093
# beverages           81923
# frozen              68202
# pantry              56681
# bakery              35806
# canned goods        32486
# deli                32008
# dry goods pasta     26096
# household           22445
# meat seafood        21588
# breakfast           21585
# personal care       13773
# babies              12872
# international        8248
# alcohol              4580
# pets                 3157
# missing              2289
# other                1097
# bulk                 1087
# Name: department, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming you already have department_count calculated
department_count = df['department'].value_counts()

# Calculate the percentage of each department
total_count = len(df)
department_percentages = (department_count / total_count) * 100

plt.figure(figsize=(10, 6))
bars = plt.bar(department_count.index, department_count.values)

# Adding labels and a title
plt.xlabel('Departments')
plt.ylabel('Frequency')
plt.title('Count of Products Ordered per Department', fontsize=20)

# Rotating the x-axis labels for better readability
plt.xticks(rotation=50)

# Adding percentage annotations on top of each bar
for bar, percentage in zip(bars, department_percentages):
    plt.annotate(f'{percentage:.2f}%', (bar.get_x() + bar.get_width() / 2, bar.get_height()), ha='center', va='bottom', fontsize=8)

# Set font size for the y-axis tick labels
plt.xticks(fontsize=10)  # Adjust the fontsize as needed

# Displaying the chart
plt.tight_layout()
plt.show()

# %%
# importing necessary libraries
import numpy as np
import pandas as pd

# %%
# reading in the csv file into a dataframe
file = 'mma_mart.csv'
df = pd.read_csv(file)

# %%
import pandas as pd
import numpy as np


# -----------------------
# Load and Explore Data
# -----------------------

column_headings = df.columns
print(column_headings)

unique_departments = df['department'].unique()
print(unique_departments)

basic_stats = df.describe()
print(basic_stats)

# -------------------------------
# Frequency Analysis of Products & Cleaning Data
# -------------------------------

# Perform a frequency analysis to count the number of times each product shows up in the dataset
product_frequency = df['product_id'].value_counts().reset_index()
product_frequency.columns = ['product_id', 'frequency']
# Out:
# Index(['order_id', 'product_id', 'product_name', 'aisle_id', 'aisle',
#        'department_id', 'department'],
#       dtype='object')
# ['dairy eggs' 'produce' 'canned goods' 'pantry' 'meat seafood' 'bakery'
#  'personal care' 'snacks' 'breakfast' 'beverages' 'deli' 'household'
#  'international' 'dry goods pasta' 'frozen' 'babies' 'pets' 'alcohol'
#  'bulk' 'missing' 'other']
#             order_id     product_id       aisle_id  department_id
# count  987259.000000  987259.000000  987259.000000  987259.000000
# mean    50018.074081   25575.839196      71.207365       9.919778
# std     28916.254672   14100.318531      38.185998       6.284092
# min         1.000000       1.000000       1.000000       1.000000
# 25%     24932.000000   13500.000000      31.000000       4.000000
# 50%     50016.000000   25256.000000      83.000000       9.000000
# 75%     75003.000000   37917.000000     107.000000      16.000000
# max    100000.000000   49688.000000     134.000000      21.000000

# %%
# Sort the products by their frequency in descending order
product_frequency_sorted = product_frequency.sort_values(by='frequency', ascending=False)

# %%
# Add product name, remove any duplicates
merged_df = pd.merge(product_frequency_sorted, df[['product_id', 'product_name', 'department']], on='product_id', how='left')
merged_df_unique = merged_df.drop_duplicates(subset=['product_id'])

# %%
# Filter the top 1000 products that have 'missing' or 'other' in the department column
ambiguous_department_products = merged_df_unique[merged_df_unique['department'].isin(['missing', 'other'])].head(100)

# %%
# To display these products, you could use:
print(ambiguous_department_products)
# Out:
#         product_id  frequency  \
# 461805       41149        243
# 570851       38662        135
# 687042       14010         72
# 696057       38510         68
# 697275        7035         67
# ...            ...        ...
# 931159       40960          7
# 931502        2353          7
# 931621       47079          7
# 931943       41543          7
# 932839        2753          7
#
#                                              product_name department
# 461805                          Organic Riced Cauliflower    missing
# 570851                              Roasted Almond Butter      other
# 687042                               Organic Mango Yogurt    missing
# 696057                               Organic Celery Bunch    missing
# 697275                        Peanut Butter Ice Cream Cup    missing
# ...                                                   ...        ...
# 931159        Organic Original Coconut Non-Dairy Beverage    missing
# 931502               Multivitamin, Kids Complete, Gummies      other
# 931621                    Fresh 'n Clean Sliced Mushrooms    missing
# 931943  Strawberry Dairy-Free Probiotic Drinkable Cash...    missing
# 932839              Blueberry Drinkable Whole Milk Yogurt    missing
#
# [100 rows x 4 columns]

# %%
# Adjust the department of "Organic Riced Cauliflower" to 'frozen'
merged_df_unique.loc[merged_df_unique['product_name'] == 'Organic Riced Cauliflower', 'department'] = 'frozen'
merged_df_unique.loc[merged_df_unique['product_name'] == 'Roasted Almond Butter', 'department'] = 'pantry'

# %%
# -------------------------
# Categorize the Products
# -------------------------

# Categroize the departments based on contraints. Classify each product as either frozen, refridgerated, or other.
frozen_products = ['frozen']
refrigerated_products = ['dairy eggs', 'meat seafood', 'deli']

# %%
# Assign category to each product in the dataset
def product_label(department):
  if department in frozen_products:
      return 'frozen'
  elif department in refrigerated_products:
      return 'refrigerated'
  else:
    return 'other'

# %%
# Apply the labels to each product
df['product_category'] = df['department'].apply(product_label)

# Count and sort each product along with its new label
product_frequency_with_category = df.groupby(['product_id', 'product_category', 'product_name', 'department']).size().reset_index(name='frequency')

product_frequency_with_category_sorted = product_frequency_with_category.sort_values(by='frequency', ascending=False)

# Display top 20 results
product_frequency_with_category_sorted.head(100)
# Out:
#        product_id product_category  \
# 17569       24852            other
# 9234        13176            other
# 14895       21137            other
# 15455       21903            other
# 33331       47209            other
# ...           ...              ...
# 27322       38689     refrigerated
# 11804       16759            other
# 14802       20995           frozen
# 21368       30233     refrigerated
# 26627       37687            other
#
#                                       product_name  department  frequency
# 17569                                       Banana     produce      14494
# 9234                        Bag of Organic Bananas     produce      11694
# 14895                         Organic Strawberries     produce       8081
# 15455                         Organic Baby Spinach     produce       7369
# 33331                         Organic Hass Avocado     produce       6411
# ...                                            ...         ...        ...
# 27322                     Organic Reduced Fat Milk  dairy eggs       1044
# 11804                         Organic Carrot Bunch     produce       1041
# 14802                     Organic Broccoli Florets      frozen       1040
# 21368  Organic Large Brown Grade AA Cage Free Eggs  dairy eggs       1034
# 26627                           Organic Spring Mix     produce       1018
#
# [100 rows x 5 columns]

# %%
# -----------------------
# Selecting top 1000 products
# -----------------------


#Selecting the top 1000 products based on the constraints
top_frozen = product_frequency_with_category_sorted[product_frequency_with_category_sorted['product_category'] == 'frozen'].head(100)
top_refrigerated = product_frequency_with_category_sorted[product_frequency_with_category_sorted['product_category'] == 'refrigerated'].head(100)
top_other = product_frequency_with_category_sorted[product_frequency_with_category_sorted['product_category'] == 'other'].head(800)

# Take the top 100 frozen products, then the top 100 refridgerated products, then fill the remainder with 800 'other' products to get a total of 1000 products
top_1000_products = pd.concat([top_frozen, top_refrigerated, top_other])

# view the top 100
top_1000_products.head(10)
# Out:
#        product_id product_category                       product_name  \
# 6393         9076           frozen                        Blueberries
# 14802       20995           frozen           Organic Broccoli Florets
# 17323       24489           frozen         Organic Whole Strawberries
# 12662       17948           frozen    Frozen Organic Wild Blueberries
# 33038       46802           frozen                   Pineapple Chunks
# 10296       14678           frozen                Organic Frozen Peas
# 26237       37158           frozen  Chicken & Maple Breakfast Sausage
# 806          1158           frozen                       Mango Chunks
# 29984       42450           frozen                  Macaroni & Cheese
# 20452       28934           frozen            Frozen Broccoli Florets
#
#       department  frequency
# 6393      frozen       1759
# 14802     frozen       1040
# 17323     frozen        983
# 12662     frozen        921
# 33038     frozen        701
# 10296     frozen        591
# 26237     frozen        566
# 806       frozen        535
# 29984     frozen        525
# 20452     frozen        483

# %%
# Check which of the top 1000 products have 'missing' or 'other' in the department column
ambiguous_department_top_1000 = top_1000_products[top_1000_products['department'].isin(['missing', 'other'])]

# Count and display the number of such products
count_ambiguous_department_top_1000 = len(ambiguous_department_top_1000)
print("Count of products with 'missing' or 'other' department:", count_ambiguous_department_top_1000)
print(ambiguous_department_top_1000)
# Out:
# Count of products with 'missing' or 'other' department: 2
#        product_id product_category               product_name department  \
# 29052       41149            other  Organic Riced Cauliflower    missing
# 27301       38662            other      Roasted Almond Butter      other
#
#        frequency
# 29052        243
# 27301        135

# %%
# -----------------------
# Count # of Orders with top 1000 products
# -----------------------

# Create a set of top 1000 product IDs for faster lookup
top_1000_product_ids = set(top_1000_products['product_id'])

# Group the original DataFrame by order IDs and aggregate the product IDs
grouped_transactions = df.groupby('order_id')['product_id'].apply(list).reset_index()

# Initialize the counter
count_orders_with_in_aisle_items = 0

# Iterate through the grouped transactions
for _, row in grouped_transactions.iterrows():
    products_in_this_order = set(row['product_id'])
    
    # Check for intersection between products in this order and the top 1000 products
    if products_in_this_order & top_1000_product_ids:
        count_orders_with_in_aisle_items += 1

# Print the count
print(f"Number of orders containing at least one top 1000 product: {count_orders_with_in_aisle_items}")
# Out:
# Number of orders containing at least one top 1000 product: 88192

# %%
# -----------------------
# Pre-Calculation Setup
# -----------------------

# Calculate the total number of unique orders
total_orders = df['order_id'].nunique()
print(total_orders)


# -----------------------
# Calculate Metric 1
# -----------------------

# Calculate the percentage of orders that contain at least one item from the top 1000 products
percentage_orders_with_in_aisle_items = (count_orders_with_in_aisle_items / total_orders) * 100

# Print the calculated metric
print(f"Percentage of orders with at least one item from top 1000 products: {percentage_orders_with_in_aisle_items:.2f}%")
# Out:
# 97833
# Percentage of orders with at least one item from top 1000 products: 90.15%

# %%
# -----------------------
# Calculate Metric 2
# -----------------------

# Calculate the total number of product entries in all orders
total_product_entries = df['product_id'].count()

# Calculate the total number of in-aisle product entries in all orders
total_in_aisle_items_in_orders = df[df['product_id'].isin(top_1000_product_ids)]['product_id'].count()


# Calculate the metrics
average_in_aisle_items_per_order = total_in_aisle_items_in_orders / total_orders
average_items_per_order = total_product_entries / total_orders
percentage_in_aisle_items_per_order = (average_in_aisle_items_per_order / average_items_per_order) * 100

# Print the calculated metrics
print(f"Average number of in-aisle items per order: {average_in_aisle_items_per_order:.2f}")
print(f"Average number of total items per order: {average_items_per_order:.2f}")
print(f"Percentage of in-aisle items per order: {percentage_in_aisle_items_per_order:.2f}%")
# Out:
# Average number of in-aisle items per order: 4.35
# Average number of total items per order: 10.09
# Percentage of in-aisle items per order: 43.12%
